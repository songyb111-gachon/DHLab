# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=100, energy_limit=200):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 100  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=200)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_100/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2340 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1666        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019956807 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.3       |
# |    explained_variance   | -2.03e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.24e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 1.67e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1595        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018345663 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.3       |
# |    explained_variance   | -3.81e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.64e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 1.73e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1559        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.016642027 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.2       |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.65e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 1.75e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1469        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.015381592 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.2       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.96e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 1.79e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1449        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014799173 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.74e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 1.81e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1417        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015866809 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.1       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 1.8e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1416        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015745442 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.08e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 1.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014983303 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -69         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 1.82e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1406        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015191704 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.1e+04     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 1.84e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016861156 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.25e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 1.86e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016527865 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.37e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0315     |
# |    value_loss           | 1.91e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015914798 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.7       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.25e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 1.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 14          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015218741 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.7e+04     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 1.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015451315 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.6       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.36e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 1.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 16          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014134925 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.96e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 1.98e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.020116169 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.94e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 2.04e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1396       |
# |    iterations           | 18         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01789411 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -68.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.96e+04   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0277    |
# |    value_loss           | 2e+05      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 19          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019033078 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 2.02e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 20          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017026292 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -68         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 2.03e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 21          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015009285 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -67.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 2.06e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 22          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017077846 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -67.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 2.07e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1395       |
# |    iterations           | 23         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01780091 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -67.7      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.04e+05   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.028     |
# |    value_loss           | 2.08e+05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1394         |
# |    iterations           | 24           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0144436415 |
# |    clip_fraction        | 0.215        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -67.6        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0248      |
# |    value_loss           | 2.12e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1394        |
# |    iterations           | 25          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.017508911 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -67.4       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0325     |
# |    value_loss           | 2.13e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 26          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.017890032 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -67.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 2.17e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1383        |
# |    iterations           | 27          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.015074002 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -67.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 2.17e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 28          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015701953 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -66.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 2.22e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 29          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015393128 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -66.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+05     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 2.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 30          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017682364 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -66.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+05    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 2.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1372        |
# |    iterations           | 31          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.017763324 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -66.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 2.26e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1369       |
# |    iterations           | 32         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01632189 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -66.2      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.12e+05   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0244    |
# |    value_loss           | 2.29e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1367        |
# |    iterations           | 33          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016358143 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -66         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 2.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 34          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.019194987 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 2.31e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 35          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014381425 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 2.36e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1361        |
# |    iterations           | 36          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013360694 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 2.34e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1359        |
# |    iterations           | 37          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.017115818 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 2.37e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 38          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.016051013 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -65         |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 2.41e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 39          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.017683327 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 2.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1353        |
# |    iterations           | 40          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015627105 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.6       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 2.42e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 41          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.017584573 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 2.43e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1353        |
# |    iterations           | 42          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.018746883 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -64.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+05    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 2.48e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1353        |
# |    iterations           | 43          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017142896 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 2.49e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1350        |
# |    iterations           | 44          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016734045 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.6       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 2.48e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 45          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.019160636 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 2.55e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1348        |
# |    iterations           | 46          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015646134 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.2       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+05     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 2.57e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1348        |
# |    iterations           | 47          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017160516 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63         |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 2.55e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1350        |
# |    iterations           | 48          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017459882 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.7       |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+05    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 2.56e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1349        |
# |    iterations           | 49          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019237913 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.6       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 2.6e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1346        |
# |    iterations           | 50          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.017682586 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.4       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 2.55e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 51          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.017971994 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+05    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 2.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 52          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.020288393 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -61.8       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+05    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 2.6e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 53          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.018210286 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -61.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+05     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 2.64e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1344        |
# |    iterations           | 54          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.018721353 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -61.3       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+05    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 2.69e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 55          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.018946987 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -61         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+05    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 2.68e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 56          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.018615078 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -60.8       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+05    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 2.7e+05     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1343      |
# |    iterations           | 57        |
# |    time_elapsed         | 86        |
# |    total_timesteps      | 116736    |
# | train/                  |           |
# |    approx_kl            | 0.0180264 |
# |    clip_fraction        | 0.25      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -60.6     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.32e+05  |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -0.0211   |
# |    value_loss           | 2.72e+05  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1344      |
# |    iterations           | 58        |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 118784    |
# | train/                  |           |
# |    approx_kl            | 0.0201673 |
# |    clip_fraction        | 0.26      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -60.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.35e+05  |
# |    n_updates            | 570       |
# |    policy_gradient_loss | -0.0219   |
# |    value_loss           | 2.73e+05  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 59          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.016467627 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -60         |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+05    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1343     |
# |    iterations           | 60       |
# |    time_elapsed         | 91       |
# |    total_timesteps      | 122880   |
# | train/                  |          |
# |    approx_kl            | 0.019309 |
# |    clip_fraction        | 0.265    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -59.7    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.36e+05 |
# |    n_updates            | 590      |
# |    policy_gradient_loss | -0.0228  |
# |    value_loss           | 2.75e+05 |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 61          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.018938571 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -59.4       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+05    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 2.74e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 62          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.017206594 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -59         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+05     |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 2.8e+05     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1340       |
# |    iterations           | 63         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.01791165 |
# |    clip_fraction        | 0.254      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -58.7      |
# |    explained_variance   | 4.77e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4e+05    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0203    |
# |    value_loss           | 2.8e+05    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1339        |
# |    iterations           | 64          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.018192217 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -58.4       |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0010215971 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 187          |
# |    n_updates            | 10390        |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 341          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 1041        |
# |    time_elapsed         | 1615        |
# |    total_timesteps      | 2131968     |
# | train/                  |             |
# |    approx_kl            | 0.000780332 |
# |    clip_fraction        | 0.00913     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 10400       |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 321         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1042         |
# |    time_elapsed         | 1616         |
# |    total_timesteps      | 2134016      |
# | train/                  |              |
# |    approx_kl            | 0.0008374408 |
# |    clip_fraction        | 0.00767      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.19        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 207          |
# |    n_updates            | 10410        |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 350          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 1043         |
# |    time_elapsed         | 1618         |
# |    total_timesteps      | 2136064      |
# | train/                  |              |
# |    approx_kl            | 0.0011783123 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 168          |
# |    n_updates            | 10420        |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 376          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1320          |
# |    iterations           | 1044          |
# |    time_elapsed         | 1619          |
# |    total_timesteps      | 2138112       |
# | train/                  |               |
# |    approx_kl            | 0.00074333785 |
# |    clip_fraction        | 0.00708       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.188        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 201           |
# |    n_updates            | 10430         |
# |    policy_gradient_loss | -0.00117      |
# |    value_loss           | 351           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1320          |
# |    iterations           | 1045          |
# |    time_elapsed         | 1621          |
# |    total_timesteps      | 2140160       |
# | train/                  |               |
# |    approx_kl            | 0.00092303404 |
# |    clip_fraction        | 0.00859       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.189        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 228           |
# |    n_updates            | 10440         |
# |    policy_gradient_loss | -0.00124      |
# |    value_loss           | 439           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1046         |
# |    time_elapsed         | 1622         |
# |    total_timesteps      | 2142208      |
# | train/                  |              |
# |    approx_kl            | 0.0012377611 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.18        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 183          |
# |    n_updates            | 10450        |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 320          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1047         |
# |    time_elapsed         | 1624         |
# |    total_timesteps      | 2144256      |
# | train/                  |              |
# |    approx_kl            | 0.0006340281 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.185       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 10460        |
# |    policy_gradient_loss | -0.000997    |
# |    value_loss           | 432          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 1048        |
# |    time_elapsed         | 1625        |
# |    total_timesteps      | 2146304     |
# | train/                  |             |
# |    approx_kl            | 0.001311285 |
# |    clip_fraction        | 0.00996     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 138         |
# |    n_updates            | 10470       |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 325         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1049         |
# |    time_elapsed         | 1627         |
# |    total_timesteps      | 2148352      |
# | train/                  |              |
# |    approx_kl            | 0.0012527725 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.176       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 10480        |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 319          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 1050        |
# |    time_elapsed         | 1628        |
# |    total_timesteps      | 2150400     |
# | train/                  |             |
# |    approx_kl            | 0.001118336 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 204         |
# |    n_updates            | 10490       |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 400         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1051         |
# |    time_elapsed         | 1630         |
# |    total_timesteps      | 2152448      |
# | train/                  |              |
# |    approx_kl            | 0.0011636871 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 247          |
# |    n_updates            | 10500        |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 527          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1052         |
# |    time_elapsed         | 1631         |
# |    total_timesteps      | 2154496      |
# | train/                  |              |
# |    approx_kl            | 0.0008642565 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.162       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 211          |
# |    n_updates            | 10510        |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 378          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 1053        |
# |    time_elapsed         | 1633        |
# |    total_timesteps      | 2156544     |
# | train/                  |             |
# |    approx_kl            | 0.000551908 |
# |    clip_fraction        | 0.00488     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 201         |
# |    n_updates            | 10520       |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 350         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1054         |
# |    time_elapsed         | 1634         |
# |    total_timesteps      | 2158592      |
# | train/                  |              |
# |    approx_kl            | 0.0011526425 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.153       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 154          |
# |    n_updates            | 10530        |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 332          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1055         |
# |    time_elapsed         | 1636         |
# |    total_timesteps      | 2160640      |
# | train/                  |              |
# |    approx_kl            | 0.0012566966 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 10540        |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 302          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1320          |
# |    iterations           | 1056          |
# |    time_elapsed         | 1637          |
# |    total_timesteps      | 2162688       |
# | train/                  |               |
# |    approx_kl            | 0.00065723876 |
# |    clip_fraction        | 0.0117        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.176        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 148           |
# |    n_updates            | 10550         |
# |    policy_gradient_loss | -0.000838     |
# |    value_loss           | 376           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1320          |
# |    iterations           | 1057          |
# |    time_elapsed         | 1639          |
# |    total_timesteps      | 2164736       |
# | train/                  |               |
# |    approx_kl            | 0.00079691946 |
# |    clip_fraction        | 0.00942       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.187        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 214           |
# |    n_updates            | 10560         |
# |    policy_gradient_loss | -0.000985     |
# |    value_loss           | 315           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1058         |
# |    time_elapsed         | 1640         |
# |    total_timesteps      | 2166784      |
# | train/                  |              |
# |    approx_kl            | 0.0012019621 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.174       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 223          |
# |    n_updates            | 10570        |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 332          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1059         |
# |    time_elapsed         | 1642         |
# |    total_timesteps      | 2168832      |
# | train/                  |              |
# |    approx_kl            | 0.0010834895 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 10580        |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 325          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 1060         |
# |    time_elapsed         | 1643         |
# |    total_timesteps      | 2170880      |
# | train/                  |              |
# |    approx_kl            | 0.0010963504 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 10590        |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 416          |
# ------------------------------------------

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
