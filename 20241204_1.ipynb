# %%
import numpy as np  # 추가된 부분
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=5, energy_limit=10):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 생성 및 래핑
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=5, energy_limit=10)])

# 로그 저장 디렉토리 설정
log_dir = "./logs/"
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000)
# Out:
# Logging to ./logs/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1381 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010395495 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | -0.000141   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.1        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 212         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010777099 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | -0.115      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 308         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009255567 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | -0.0393     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 276         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009507289 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.33       |
# |    explained_variance   | -0.0217     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 359         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009910591 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | -0.00384    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 118         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 329         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010160971 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | -0.00132    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 319         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 8           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012106095 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | -0.00293    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 298         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009647337 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.000793    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 306         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011297777 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | -0.000218   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 341         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011273032 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.000254    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 121         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 343         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013243848 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | -0.000461   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 322         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 13          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013899669 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 3.58e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 347         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 14          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019808495 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 1.2e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 312         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 865        |
# |    iterations           | 15         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.02487857 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | 2.55e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 136        |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0133    |
# |    value_loss           | 358        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 16           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0145840505 |
# |    clip_fraction        | 0.0893       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00771     |
# |    value_loss           | 374          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 17           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0077380934 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -1.19e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 348          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015801977 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 3.22e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 323         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 19          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012082302 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.934      |
# |    explained_variance   | 1.67e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 316         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 20          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.005966243 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 274         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 863          |
# |    iterations           | 21           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0030956243 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97           |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 277          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 861        |
# |    iterations           | 22         |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00393441 |
# |    clip_fraction        | 0.0394     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.643     |
# |    explained_variance   | 1.37e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 78         |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00391   |
# |    value_loss           | 255        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 23           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0025912938 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.8         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 244          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 24           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0023577707 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.6         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00331     |
# |    value_loss           | 213          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 25           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0015618361 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.3         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 193          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 26           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024046537 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40           |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00541     |
# |    value_loss           | 155          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 27           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0014564253 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.434       |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 28           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0025454378 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.376       |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.7         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 29           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0013949497 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.7         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 30          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.000762946 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000817   |
# |    value_loss           | 76.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 31           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0010682469 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.289       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 65.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 32           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0010664875 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.3          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 44.6         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 862           |
# |    iterations           | 33            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00088220893 |
# |    clip_fraction        | 0.00562       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.237        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.26          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 41.7          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 34           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0006169238 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.37         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000351    |
# |    value_loss           | 37.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 863          |
# |    iterations           | 35           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0004886467 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.183       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.66         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00023     |
# |    value_loss           | 26.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 863          |
# |    iterations           | 36           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0021852432 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.14         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000943    |
# |    value_loss           | 23.5         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 862           |
# |    iterations           | 37            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 0.00053666346 |
# |    clip_fraction        | 0.00669       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.159        |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.23          |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000519     |
# |    value_loss           | 26            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 38           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0007025149 |
# |    clip_fraction        | 0.00908      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.155       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.33         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000939    |
# |    value_loss           | 21           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 39           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0005708588 |
# |    clip_fraction        | 0.00713      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.163       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.78         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000414    |
# |    value_loss           | 14           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 40           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0005386057 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.96         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000651    |
# |    value_loss           | 17.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 41           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0004421143 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.158       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000123    |
# |    value_loss           | 23.6         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 862           |
# |    iterations           | 42            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00036837102 |
# |    clip_fraction        | 0.00474       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.139        |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.09          |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000389     |
# |    value_loss           | 16.3          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 43          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.000582404 |
# |    clip_fraction        | 0.00918     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.127      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.31        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000396   |
# |    value_loss           | 16.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 44           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0004467482 |
# |    clip_fraction        | 0.00649      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.114       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.79         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00091     |
# |    value_loss           | 18.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 862           |
# |    iterations           | 45            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00047501706 |
# |    clip_fraction        | 0.00464       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.105        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.77          |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000668     |
# |    value_loss           | 16.7          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 46           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0004933438 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0993      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.24         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000765    |
# |    value_loss           | 17.9         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 47            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00045638334 |
# |    clip_fraction        | 0.00825       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0932       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.3           |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 23.6          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 48            |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00035782848 |
# |    clip_fraction        | 0.00771       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.101        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.76          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000809     |
# |    value_loss           | 18            |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 49            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00041285055 |
# |    clip_fraction        | 0.00757       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0993       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.08          |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000728     |
# |    value_loss           | 19            |
# -------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

# CSV 로그 파일 경로
log_csv_path = "./logs/progress.csv"

# CSV 파일 읽기
data = pd.read_csv(log_csv_path)

# 주요 메트릭 시각화
plt.figure(figsize=(10, 6))

# 학습 손실 시각화
plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")

# 그래프 레이블 설정
plt.xlabel("Timesteps")
plt.ylabel("Loss")
plt.title("Training Loss Over Timesteps")
plt.legend()
plt.grid()
plt.show()

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# 학습된 모델 평가
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, render=False)
print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")

# 보상 시뮬레이션
rewards = []
obs = env.reset()
for _ in range(1000):
    action, _ = model.predict(obs)
    obs, reward, done, _ = env.step(action)
    rewards.append(reward)
    if done:
        obs = env.reset()

# 보상 시각화
plt.figure(figsize=(10, 6))
plt.plot(rewards, label="Reward")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.title("Rewards Over Steps")
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 from stable_baselines3.common.evaluation import evaluate_policy
#       3 # 학습된 모델 평가
# ----> 4 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, render=False)
#       5 print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
#       7 # 보상 시뮬레이션
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# Cell In[1], line 31, in SmartFactoryEnv.step(self, action)
#      30 def step(self, action):
# ---> 31     energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
#      32     production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
#      33     penalty = max(0, energy_usage - self.energy_limit)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# 학습된 모델 평가
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, render=False)

print(f"Mean reward: {mean_reward:.2f} ± {std_reward:.2f}")
