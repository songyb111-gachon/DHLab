# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=289, energy_limit=578):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 289 # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=578)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_289/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2398 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1636      |
# |    iterations           | 2         |
# |    time_elapsed         | 2         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0256501 |
# |    clip_fraction        | 0.263     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -200      |
# |    explained_variance   | 7.24e-05  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.28e+05  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -0.0331   |
# |    value_loss           | 1.45e+06  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.026871365 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.11e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 1.45e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1421       |
# |    iterations           | 4          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02300552 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -200       |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.31e+05   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0363    |
# |    value_loss           | 1.48e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1373        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.023003241 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.31e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 1.48e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1345       |
# |    iterations           | 6          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02477941 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -200       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.34e+05   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0361    |
# |    value_loss           | 1.47e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024718314 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0399     |
# |    value_loss           | 1.5e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1306        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.024522517 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.66e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 1.52e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.025919205 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.6e+05     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 1.51e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1304        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023270011 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.62e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 1.52e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1294       |
# |    iterations           | 11         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02596741 |
# |    clip_fraction        | 0.295      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -200       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.65e+05   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0364    |
# |    value_loss           | 1.53e+06   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1296       |
# |    iterations           | 12         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02294748 |
# |    clip_fraction        | 0.274      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -200       |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.78e+05   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0335    |
# |    value_loss           | 1.55e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1296        |
# |    iterations           | 13          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.024258273 |
# |    clip_fraction        | 0.281       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.74e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 1.56e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 14          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.023903336 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.8e+05     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 1.57e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 15          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.027015178 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -200        |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.85e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 1.56e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 16          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024928242 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.68e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 1.57e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 17          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.027055401 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.88e+05    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 1.6e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1287        |
# |    iterations           | 18          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.025773041 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.92e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 1.61e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1280        |
# |    iterations           | 19          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.025160141 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.13e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 1.62e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 20          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.026748128 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.99e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 1.62e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 21          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.026679952 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.29e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0337     |
# |    value_loss           | 1.65e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1284       |
# |    iterations           | 22         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.02736009 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -199       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.2e+05    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0367    |
# |    value_loss           | 1.65e+06   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1274       |
# |    iterations           | 23         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02531633 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -199       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.3e+05    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0349    |
# |    value_loss           | 1.66e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1275        |
# |    iterations           | 24          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025724541 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -199        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.19e+05    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 1.67e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1274        |
# |    iterations           | 25          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.027317766 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.35e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 1.68e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 26          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.027192015 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.27e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 1.68e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1272        |
# |    iterations           | 27          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.027836787 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.52e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.7e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1271        |
# |    iterations           | 28          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.029715369 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.63e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 1.72e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1269        |
# |    iterations           | 29          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.028735705 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.69e+05    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 1.73e+06    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1268      |
# |    iterations           | 30        |
# |    time_elapsed         | 48        |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0280318 |
# |    clip_fraction        | 0.312     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -198      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.49e+05  |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.0343   |
# |    value_loss           | 1.73e+06  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 31          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.028264249 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -198        |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.65e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0343     |
# |    value_loss           | 1.74e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 32          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.028962903 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -197        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.42e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 1.74e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1261        |
# |    iterations           | 33          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.026614815 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -197        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.69e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 1.76e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 34          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.027171088 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -197        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.86e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.77e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1259       |
# |    iterations           | 35         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02785423 |
# |    clip_fraction        | 0.314      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -197       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.86e+05   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0353    |
# |    value_loss           | 1.78e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 36          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.028882695 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -197        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.08e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.79e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 37          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.028481938 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -196        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.98e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 1.81e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 38          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.029790591 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -196        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.85e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 1.81e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 39          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.028346313 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -196        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.13e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 1.83e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 40          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.030200336 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -196        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.25e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0376     |
# |    value_loss           | 1.84e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 41          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.027640719 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -195        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.12e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 1.84e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1269       |
# |    iterations           | 42         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.02630502 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -195       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.27e+05   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0309    |
# |    value_loss           | 1.84e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 43          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.029442042 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -195        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.33e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 1.88e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 44          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.026471779 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -195        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.4e+05     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 1.87e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1264       |
# |    iterations           | 45         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02847796 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -194       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.34e+05   |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0349    |
# |    value_loss           | 1.89e+06   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1263       |
# |    iterations           | 46         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.03056832 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -194       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.62e+05   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0341    |
# |    value_loss           | 1.92e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1264        |
# |    iterations           | 47          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.027226985 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -194        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.76e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 1.94e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1265        |
# |    iterations           | 48          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.027908046 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -194        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.26e+05    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.91e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 49          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.031911843 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -193        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.66e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0345     |
# |    value_loss           | 1.94e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 50          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.030542027 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -193        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.77e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 1.97e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1270        |
# |    iterations           | 51          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.027880227 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -193        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.62e+05    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 1.95e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1273        |
# |    iterations           | 52          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.025529955 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -192        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.9e+05     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0312     |
# |    value_loss           | 1.96e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1271        |
# |    iterations           | 53          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.028252836 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -192        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.94e+05    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 1.98e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1271        |
# |    iterations           | 54          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.028198037 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -192        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+06       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 2e+06       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1270      |
# |    iterations           | 55        |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 112640    |
# | train/                  |           |
# |    approx_kl            | 0.0295411 |
# |    clip_fraction        | 0.32      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -192      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.93e+05  |
# |    n_updates            | 540       |
# |    policy_gradient_loss | -0.037    |
# |    value_loss           | 2.01e+06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1269      |
# |    iterations           | 56        |
# |    time_elapsed         | 90        |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0298239 |
# |    clip_fraction        | 0.342     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -191      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.01e+06  |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0347   |
# |    value_loss           | 2.02e+06  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1268        |
# |    iterations           | 57          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.028642427 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -191        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.89e+05    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 2.03e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 58          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.029951284 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -191        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+06    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 2.05e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1266       |
# |    iterations           | 59         |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.02864859 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -190       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.01e+06   |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0331    |
# |    value_loss           | 2.04e+06   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1265       |
# |    iterations           | 60         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.02951999 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -190       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.04e+06   |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0327    |
# |    value_loss           | 2.05e+06   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1263       |
# |    iterations           | 61         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.02834388 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -190       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.05e+06   |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0317    |
# |    value_loss           | 2.08e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1262        |
# |    iterations           | 62          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.030113325 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -190        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+06    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 2.08e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1259        |
# |    iterations           | 63          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.030278552 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -189        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+06    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 2.08e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1260        |
# |    iterations           | 64          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.027008558 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -189        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+06    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.0311     |
# ...
# |    learning_rate        | 0.0003        |
# |    loss                 | 516           |
# |    n_updates            | 40260         |
# |    policy_gradient_loss | -0.000328     |
# |    value_loss           | 1.14e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4028          |
# |    time_elapsed         | 6236          |
# |    total_timesteps      | 8249344       |
# | train/                  |               |
# |    approx_kl            | 0.00026345166 |
# |    clip_fraction        | 0.0022        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0946       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 324           |
# |    n_updates            | 40270         |
# |    policy_gradient_loss | -0.000559     |
# |    value_loss           | 788           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4029          |
# |    time_elapsed         | 6238          |
# |    total_timesteps      | 8251392       |
# | train/                  |               |
# |    approx_kl            | 0.00036909853 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0911       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 358           |
# |    n_updates            | 40280         |
# |    policy_gradient_loss | -0.000166     |
# |    value_loss           | 742           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4030          |
# |    time_elapsed         | 6240          |
# |    total_timesteps      | 8253440       |
# | train/                  |               |
# |    approx_kl            | 0.00017568807 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0897       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 460           |
# |    n_updates            | 40290         |
# |    policy_gradient_loss | -3.36e-05     |
# |    value_loss           | 838           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 4031         |
# |    time_elapsed         | 6241         |
# |    total_timesteps      | 8255488      |
# | train/                  |              |
# |    approx_kl            | 0.0006691809 |
# |    clip_fraction        | 0.00361      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0842      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 691          |
# |    n_updates            | 40300        |
# |    policy_gradient_loss | -0.000636    |
# |    value_loss           | 1.2e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4032          |
# |    time_elapsed         | 6243          |
# |    total_timesteps      | 8257536       |
# | train/                  |               |
# |    approx_kl            | 0.00024641346 |
# |    clip_fraction        | 0.00117       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0801       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 501           |
# |    n_updates            | 40310         |
# |    policy_gradient_loss | -0.000296     |
# |    value_loss           | 1.1e+03       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4033          |
# |    time_elapsed         | 6244          |
# |    total_timesteps      | 8259584       |
# | train/                  |               |
# |    approx_kl            | 0.00023942813 |
# |    clip_fraction        | 0.00347       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0791       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 879           |
# |    n_updates            | 40320         |
# |    policy_gradient_loss | -0.000509     |
# |    value_loss           | 1.46e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4034          |
# |    time_elapsed         | 6246          |
# |    total_timesteps      | 8261632       |
# | train/                  |               |
# |    approx_kl            | 0.00014895966 |
# |    clip_fraction        | 0.00151       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.082        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 716           |
# |    n_updates            | 40330         |
# |    policy_gradient_loss | -0.000204     |
# |    value_loss           | 1.1e+03       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4035          |
# |    time_elapsed         | 6248          |
# |    total_timesteps      | 8263680       |
# | train/                  |               |
# |    approx_kl            | 0.00022667591 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0759       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 538           |
# |    n_updates            | 40340         |
# |    policy_gradient_loss | -8.42e-05     |
# |    value_loss           | 1.13e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 4036         |
# |    time_elapsed         | 6249         |
# |    total_timesteps      | 8265728      |
# | train/                  |              |
# |    approx_kl            | 0.0002747388 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0727      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 551          |
# |    n_updates            | 40350        |
# |    policy_gradient_loss | -0.000653    |
# |    value_loss           | 1.02e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4037          |
# |    time_elapsed         | 6251          |
# |    total_timesteps      | 8267776       |
# | train/                  |               |
# |    approx_kl            | 0.00051586586 |
# |    clip_fraction        | 0.0084        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0625       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 407           |
# |    n_updates            | 40360         |
# |    policy_gradient_loss | -0.00157      |
# |    value_loss           | 948           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4038          |
# |    time_elapsed         | 6253          |
# |    total_timesteps      | 8269824       |
# | train/                  |               |
# |    approx_kl            | 0.00029636262 |
# |    clip_fraction        | 0.00581       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.056        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 366           |
# |    n_updates            | 40370         |
# |    policy_gradient_loss | -0.000621     |
# |    value_loss           | 999           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4039          |
# |    time_elapsed         | 6254          |
# |    total_timesteps      | 8271872       |
# | train/                  |               |
# |    approx_kl            | 0.00012846933 |
# |    clip_fraction        | 0.00107       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0626       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 658           |
# |    n_updates            | 40380         |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 1.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4040          |
# |    time_elapsed         | 6256          |
# |    total_timesteps      | 8273920       |
# | train/                  |               |
# |    approx_kl            | 0.00042155304 |
# |    clip_fraction        | 0.00596       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0671       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 551           |
# |    n_updates            | 40390         |
# |    policy_gradient_loss | -0.000794     |
# |    value_loss           | 945           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4041          |
# |    time_elapsed         | 6258          |
# |    total_timesteps      | 8275968       |
# | train/                  |               |
# |    approx_kl            | 0.00053807645 |
# |    clip_fraction        | 0.00508       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0658       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 610           |
# |    n_updates            | 40400         |
# |    policy_gradient_loss | -0.000778     |
# |    value_loss           | 1.13e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 4042         |
# |    time_elapsed         | 6259         |
# |    total_timesteps      | 8278016      |
# | train/                  |              |
# |    approx_kl            | 0.0005569842 |
# |    clip_fraction        | 0.00493      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0739      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 432          |
# |    n_updates            | 40410        |
# |    policy_gradient_loss | -0.000297    |
# |    value_loss           | 898          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 4043         |
# |    time_elapsed         | 6261         |
# |    total_timesteps      | 8280064      |
# | train/                  |              |
# |    approx_kl            | 0.0003625123 |
# |    clip_fraction        | 0.00337      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0784      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 423          |
# |    n_updates            | 40420        |
# |    policy_gradient_loss | -0.000548    |
# |    value_loss           | 858          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 4044         |
# |    time_elapsed         | 6263         |
# |    total_timesteps      | 8282112      |
# | train/                  |              |
# |    approx_kl            | 0.0003800687 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0889      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 641          |
# |    n_updates            | 40430        |
# |    policy_gradient_loss | -0.000613    |
# |    value_loss           | 1.07e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1322         |
# |    iterations           | 4045         |
# |    time_elapsed         | 6264         |
# |    total_timesteps      | 8284160      |
# | train/                  |              |
# |    approx_kl            | 0.0002658859 |
# |    clip_fraction        | 0.00239      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0937      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 477          |
# |    n_updates            | 40440        |
# |    policy_gradient_loss | -0.000583    |
# |    value_loss           | 1.1e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1322          |
# |    iterations           | 4046          |
# |    time_elapsed         | 6266          |
# |    total_timesteps      | 8286208       |
# | train/                  |               |
# |    approx_kl            | 0.00039306527 |
# |    clip_fraction        | 0.00659       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.105        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 506           |
# |    n_updates            | 40450         |
# |    policy_gradient_loss | -0.000346     |
# |    value_loss           | 1.04e+03      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1322        |
# |    iterations           | 4047        |
# |    time_elapsed         | 6267        |
# |    total_timesteps      | 8288256     |
# | train/                  |             |
# |    approx_kl            | 0.000515153 |
# |    clip_fraction        | 0.00581     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0932     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 428         |
# |    n_updates            | 40460       |
# |    policy_gradient_loss | -0.000679   |
# |    value_loss           | 894         |
# -----------------------------------------

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
