# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=25, energy_limit=50):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 25  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=50)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=1000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_25/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2481 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1695        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013087232 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.3       |
# |    explained_variance   | 0.000414    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.2e+03     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 9.24e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1505       |
# |    iterations           | 3          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01254338 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -17.3      |
# |    explained_variance   | -0.000127  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.76e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 1.04e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1471        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010285528 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.3       |
# |    explained_variance   | -2.68e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.9e+03     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1453        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011463722 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | -2.91e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.07e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 1.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1394        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009049515 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | -1.03e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.24e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 1.15e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1406        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008915638 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | 4.77e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.16e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 1.12e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1411         |
# |    iterations           | 8            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0105889365 |
# |    clip_fraction        | 0.149        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -17          |
# |    explained_variance   | -5.25e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.45e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0162      |
# |    value_loss           | 1.16e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1419        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011171062 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17         |
# |    explained_variance   | -4.77e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.41e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 1.17e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1383        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011994362 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -3.22e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7e+03     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 1.21e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010884741 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.7       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.56e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.011035826 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.6       |
# |    explained_variance   | -3.46e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.89e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 1.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1384        |
# |    iterations           | 13          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011309107 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.78e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 1.24e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1393        |
# |    iterations           | 14          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010285597 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.4       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 1.32e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011565013 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.18e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 1.34e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1399       |
# |    iterations           | 16         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01030116 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -16.1      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.8e+03    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 1.28e+04   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1387       |
# |    iterations           | 17         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00924577 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15.9      |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.64e+03   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 1.4e+04    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1383        |
# |    iterations           | 18          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009531438 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.8       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.42e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 1.37e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 19          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.010865067 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.6       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.77e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 1.39e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1391        |
# |    iterations           | 20          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009689862 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.83e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 1.43e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1394       |
# |    iterations           | 21         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01177346 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15.2      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.04e+03   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 1.48e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 22          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010587361 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.98e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 1.47e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 23          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010832721 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.8       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.97e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 1.47e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 24          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012911728 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.01e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 1.48e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 25          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010579623 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.44e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 1.54e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1390        |
# |    iterations           | 26          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012803834 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.47e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 1.57e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1389        |
# |    iterations           | 27          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008872137 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.58e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 1.59e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1389         |
# |    iterations           | 28           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0117352735 |
# |    clip_fraction        | 0.175        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -13.6        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.68e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0158      |
# |    value_loss           | 1.6e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1390        |
# |    iterations           | 29          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010454211 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.3       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.68e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 1.6e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1387        |
# |    iterations           | 30          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010396598 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.85e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 1.63e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1389         |
# |    iterations           | 31           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0100699505 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -12.7        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.87e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0128      |
# |    value_loss           | 1.66e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1381        |
# |    iterations           | 32          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011597464 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.9e+03     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1382        |
# |    iterations           | 33          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010707728 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.78e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 1.67e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1384        |
# |    iterations           | 34          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.010222418 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.82e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.009      |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1383        |
# |    iterations           | 35          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009881383 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.79e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.69e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1383        |
# |    iterations           | 36          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009482844 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.6       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.39e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 1.74e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 37          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011954658 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 1.67e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1387        |
# |    iterations           | 38          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011016764 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.52e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 1.74e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1388        |
# |    iterations           | 39          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010109531 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.25e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 1.73e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1390        |
# |    iterations           | 40          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010231312 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.06e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 1.71e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1388       |
# |    iterations           | 41         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01021283 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.49e+03   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00844   |
# |    value_loss           | 1.77e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1390        |
# |    iterations           | 42          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008538948 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.17e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00864    |
# |    value_loss           | 1.77e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 43          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.011899952 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.74       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.67e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 1.79e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1393        |
# |    iterations           | 44          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012478883 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.42e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 1.75e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1395        |
# |    iterations           | 45          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010596011 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.28       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.54e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 1.79e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1397       |
# |    iterations           | 46         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01296632 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.96      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.52e+03   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 1.8e+04    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 47          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010949421 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.67       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.37e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00924    |
# |    value_loss           | 1.74e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1399        |
# |    iterations           | 48          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011967532 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.35       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.57e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 1.81e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 49          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011140814 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.1        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.57e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 1.78e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1397       |
# |    iterations           | 50         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01378404 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.77      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.51e+03   |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 1.79e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 51          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.013098741 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.48       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2e+03     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.73e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 52          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012324728 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.16       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.21e+03    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 53          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.012796804 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.9        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.56e+03    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 1.81e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1399        |
# |    iterations           | 54          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.011432196 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.64       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.5e+03     |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 1.8e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 55          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.011148132 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.33       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.34e+03    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00924    |
# |    value_loss           | 1.77e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1399        |
# |    iterations           | 56          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012697667 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.02       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.33e+03    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 1.73e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 57          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.012401201 |
# |    clip_fraction        | 0.0979      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.73       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.68e+03    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 1.82e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 58          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.013402548 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.98e+03    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00871    |
# |    value_loss           | 1.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 59          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.010293521 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.03       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.41e+03    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 1.79e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 60          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.012736382 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.72e+03    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 1.84e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 61          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.010624969 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.57       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.48e+03    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 1.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1404        |
# |    iterations           | 62          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.009795873 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.43e+03    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 1.78e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1405         |
# |    iterations           | 63           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0073427195 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.92e+03     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00428     |
# |    value_loss           | 1.72e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1406        |
# |    iterations           | 64          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009516578 |
# ...
# |    loss                 | 36.7          |
# |    n_updates            | 4380          |
# |    policy_gradient_loss | -0.000162     |
# |    value_loss           | 89            |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1392          |
# |    iterations           | 440           |
# |    time_elapsed         | 646           |
# |    total_timesteps      | 901120        |
# | train/                  |               |
# |    approx_kl            | 0.00014792406 |
# |    clip_fraction        | 0.00112       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0166       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 62.2          |
# |    n_updates            | 4390          |
# |    policy_gradient_loss | -0.000248     |
# |    value_loss           | 114           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1392          |
# |    iterations           | 441           |
# |    time_elapsed         | 648           |
# |    total_timesteps      | 903168        |
# | train/                  |               |
# |    approx_kl            | 0.00014811855 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0165       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 35.4          |
# |    n_updates            | 4400          |
# |    policy_gradient_loss | -0.000285     |
# |    value_loss           | 81.4          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1392          |
# |    iterations           | 442           |
# |    time_elapsed         | 649           |
# |    total_timesteps      | 905216        |
# | train/                  |               |
# |    approx_kl            | 4.1945696e-05 |
# |    clip_fraction        | 0.000781      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0158       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 42            |
# |    n_updates            | 4410          |
# |    policy_gradient_loss | -6.71e-05     |
# |    value_loss           | 80.8          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1392          |
# |    iterations           | 443           |
# |    time_elapsed         | 651           |
# |    total_timesteps      | 907264        |
# | train/                  |               |
# |    approx_kl            | 1.5078731e-05 |
# |    clip_fraction        | 0.000195      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0158       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 50.3          |
# |    n_updates            | 4420          |
# |    policy_gradient_loss | -8.21e-05     |
# |    value_loss           | 89.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1392         |
# |    iterations           | 444          |
# |    time_elapsed         | 652          |
# |    total_timesteps      | 909312       |
# | train/                  |              |
# |    approx_kl            | 4.105694e-05 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0151      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.4         |
# |    n_updates            | 4430         |
# |    policy_gradient_loss | -0.000246    |
# |    value_loss           | 88.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1392         |
# |    iterations           | 445          |
# |    time_elapsed         | 654          |
# |    total_timesteps      | 911360       |
# | train/                  |              |
# |    approx_kl            | 7.263509e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0149      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.2         |
# |    n_updates            | 4440         |
# |    policy_gradient_loss | 2.45e-09     |
# |    value_loss           | 89           |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1393          |
# |    iterations           | 446           |
# |    time_elapsed         | 655           |
# |    total_timesteps      | 913408        |
# | train/                  |               |
# |    approx_kl            | 0.00010075247 |
# |    clip_fraction        | 0.000635      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0146       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 44.8          |
# |    n_updates            | 4450          |
# |    policy_gradient_loss | -0.000118     |
# |    value_loss           | 93            |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1393          |
# |    iterations           | 447           |
# |    time_elapsed         | 657           |
# |    total_timesteps      | 915456        |
# | train/                  |               |
# |    approx_kl            | 6.5476546e-05 |
# |    clip_fraction        | 0.000586      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0142       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 47.8          |
# |    n_updates            | 4460          |
# |    policy_gradient_loss | -0.000109     |
# |    value_loss           | 101           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1393          |
# |    iterations           | 448           |
# |    time_elapsed         | 658           |
# |    total_timesteps      | 917504        |
# | train/                  |               |
# |    approx_kl            | 3.7437145e-05 |
# |    clip_fraction        | 0.000684      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0138       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 35.7          |
# |    n_updates            | 4470          |
# |    policy_gradient_loss | -0.000165     |
# |    value_loss           | 76.8          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1392         |
# |    iterations           | 449          |
# |    time_elapsed         | 660          |
# |    total_timesteps      | 919552       |
# | train/                  |              |
# |    approx_kl            | 6.649279e-05 |
# |    clip_fraction        | 0.00103      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0149      |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.8         |
# |    n_updates            | 4480         |
# |    policy_gradient_loss | -0.00013     |
# |    value_loss           | 78.6         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1392          |
# |    iterations           | 450           |
# |    time_elapsed         | 661           |
# |    total_timesteps      | 921600        |
# | train/                  |               |
# |    approx_kl            | 1.3287915e-05 |
# |    clip_fraction        | 0.000391      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0143       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.9          |
# |    n_updates            | 4490          |
# |    policy_gradient_loss | -7.05e-05     |
# |    value_loss           | 98.2          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1392          |
# |    iterations           | 451           |
# |    time_elapsed         | 663           |
# |    total_timesteps      | 923648        |
# | train/                  |               |
# |    approx_kl            | 2.9140438e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0142       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 39.4          |
# |    n_updates            | 4500          |
# |    policy_gradient_loss | 4.51e-10      |
# |    value_loss           | 80.2          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1392         |
# |    iterations           | 452          |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 925696       |
# | train/                  |              |
# |    approx_kl            | 0.0001434708 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0154      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.6         |
# |    n_updates            | 4510         |
# |    policy_gradient_loss | -8.39e-05    |
# |    value_loss           | 84.1         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1391          |
# |    iterations           | 453           |
# |    time_elapsed         | 666           |
# |    total_timesteps      | 927744        |
# | train/                  |               |
# |    approx_kl            | 0.00010657484 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.016        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 42.9          |
# |    n_updates            | 4520          |
# |    policy_gradient_loss | -0.000167     |
# |    value_loss           | 96.1          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1391          |
# |    iterations           | 454           |
# |    time_elapsed         | 668           |
# |    total_timesteps      | 929792        |
# | train/                  |               |
# |    approx_kl            | 7.4787735e-05 |
# |    clip_fraction        | 0.000928      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.017        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 60.2          |
# |    n_updates            | 4530          |
# |    policy_gradient_loss | -0.000195     |
# |    value_loss           | 119           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1391          |
# |    iterations           | 455           |
# |    time_elapsed         | 669           |
# |    total_timesteps      | 931840        |
# | train/                  |               |
# |    approx_kl            | 0.00015943887 |
# |    clip_fraction        | 0.00181       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0155       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 64.5          |
# |    n_updates            | 4540          |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 103           |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1391           |
# |    iterations           | 456            |
# |    time_elapsed         | 671            |
# |    total_timesteps      | 933888         |
# | train/                  |                |
# |    approx_kl            | -3.7012228e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.0147        |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 51.7           |
# |    n_updates            | 4550           |
# |    policy_gradient_loss | -2.37e-09      |
# |    value_loss           | 115            |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1391         |
# |    iterations           | 457          |
# |    time_elapsed         | 672          |
# |    total_timesteps      | 935936       |
# | train/                  |              |
# |    approx_kl            | 0.0005726591 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0144      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.7         |
# |    n_updates            | 4560         |
# |    policy_gradient_loss | -0.000534    |
# |    value_loss           | 81.4         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1391          |
# |    iterations           | 458           |
# |    time_elapsed         | 674           |
# |    total_timesteps      | 937984        |
# | train/                  |               |
# |    approx_kl            | 6.1349914e-05 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0156       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 44.9          |
# |    n_updates            | 4570          |
# |    policy_gradient_loss | -0.000158     |
# |    value_loss           | 87.6          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1391          |
# |    iterations           | 459           |
# |    time_elapsed         | 675           |
# |    total_timesteps      | 940032        |
# | train/                  |               |
# |    approx_kl            | 0.00044022905 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0196       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 37.1          |
# |    n_updates            | 4580          |
# |    policy_gradient_loss | -0.000229     |
# |    value_loss           | 92.1          |
# -------------------------------------------

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
