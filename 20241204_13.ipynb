# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=169, energy_limit=338):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 169  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=338)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_169/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2345 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1665        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.025061369 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | 0.000102    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0289     |
# |    value_loss           | 4.87e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1520        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.023549065 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | -9.54e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.4e+05     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 4.91e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1431        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.022351962 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 5.03e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1404        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.023147058 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 5.1e+05     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1368       |
# |    iterations           | 6          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.02139821 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -117       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.47e+05   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0275    |
# |    value_loss           | 5.12e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.022159107 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 5.15e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1350       |
# |    iterations           | 8          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02010185 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -117       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.54e+05   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.028     |
# |    value_loss           | 5.13e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.021321451 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6e+05     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0311     |
# |    value_loss           | 5.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.020202413 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0301     |
# |    value_loss           | 5.24e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021927897 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7e+05     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 5.32e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1363       |
# |    iterations           | 12         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02039051 |
# |    clip_fraction        | 0.261      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -117       |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.66e+05   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0288    |
# |    value_loss           | 5.32e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1362        |
# |    iterations           | 13          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021528002 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -117        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 5.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1349        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.022082783 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 5.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 15          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019156676 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 5.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1347        |
# |    iterations           | 16          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021892022 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 5.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1349        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022333873 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78e+05    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0296     |
# |    value_loss           | 5.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 18          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.021439977 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.029      |
# |    value_loss           | 5.59e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 19          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.023044027 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.79e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 5.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1329        |
# |    iterations           | 20          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.023509182 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.88e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 5.77e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 21          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.021845747 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.87e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0309     |
# |    value_loss           | 5.73e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.023922708 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -116        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.91e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 5.82e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 23          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.024619233 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 5.87e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 24          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.023489129 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.88e+05    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 5.84e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1319       |
# |    iterations           | 25         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02248415 |
# |    clip_fraction        | 0.276      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -115       |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.97e+05   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0266    |
# |    value_loss           | 5.97e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 26          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021379292 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.029      |
# |    value_loss           | 5.86e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1312        |
# |    iterations           | 27          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.020100066 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.04e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 6.04e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1316        |
# |    iterations           | 28          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025273824 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -115        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0298     |
# |    value_loss           | 6.06e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1315       |
# |    iterations           | 29         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02381808 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -115       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.03e+05   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0297    |
# |    value_loss           | 6.09e+05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1313       |
# |    iterations           | 30         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.02347766 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -114       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.03e+05   |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0307    |
# |    value_loss           | 6.17e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 31          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.019600444 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -114        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.13e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 6.22e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1309        |
# |    iterations           | 32          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021822656 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -114        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.02e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0287     |
# |    value_loss           | 6.19e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1311        |
# |    iterations           | 33          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.022854054 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -114        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.12e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 6.23e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1313       |
# |    iterations           | 34         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.02443094 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -113       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.21e+05   |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 6.39e+05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1309       |
# |    iterations           | 35         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02528942 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -113       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.24e+05   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.028     |
# |    value_loss           | 6.45e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1310        |
# |    iterations           | 36          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.025610562 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2e+05     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 6.5e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1312        |
# |    iterations           | 37          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.024307137 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -113        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.35e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 6.62e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 38          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.025375377 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2e+05     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 6.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1315        |
# |    iterations           | 39          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.025898617 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 6.64e+05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1318      |
# |    iterations           | 40        |
# |    time_elapsed         | 62        |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0266184 |
# |    clip_fraction        | 0.332     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -112      |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.31e+05  |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.0287   |
# |    value_loss           | 6.73e+05  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 41          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.023177704 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 6.8e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 42          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024550363 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -112        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.45e+05    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 6.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1314        |
# |    iterations           | 43          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.026337985 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0287     |
# |    value_loss           | 6.83e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1317       |
# |    iterations           | 44         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.02637859 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -111       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.39e+05   |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.025     |
# |    value_loss           | 6.89e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1317        |
# |    iterations           | 45          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.021755356 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.44e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 6.86e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 46          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.023183234 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.43e+05    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 6.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1318        |
# |    iterations           | 47          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.027411012 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -111        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 6.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 48          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.024306092 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -110        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.52e+05    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 7.02e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1319        |
# |    iterations           | 49          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.025083754 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -110        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 7.08e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1320        |
# |    iterations           | 50          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.022718182 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -110        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 7.03e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1323       |
# |    iterations           | 51         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.02857782 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -110       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.48e+05   |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0294    |
# |    value_loss           | 7.13e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 52          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.024059873 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53e+05    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 7.16e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 53          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.025372278 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -109        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.66e+05    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 7.28e+05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1327      |
# |    iterations           | 54        |
# |    time_elapsed         | 83        |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 0.0241785 |
# |    clip_fraction        | 0.305     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -109      |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.65e+05  |
# |    n_updates            | 530       |
# |    policy_gradient_loss | -0.0258   |
# |    value_loss           | 7.19e+05  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1329        |
# |    iterations           | 55          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.026304564 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -108        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.58e+05    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 7.23e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 56          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.027454011 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -108        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64e+05    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 7.34e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1329        |
# |    iterations           | 57          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.027087925 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -108        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.69e+05    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 7.37e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 58          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.025256319 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -108        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72e+05    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 7.44e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1332        |
# |    iterations           | 59          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.022541627 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.75e+05    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 7.45e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1333       |
# |    iterations           | 60         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.02311678 |
# |    clip_fraction        | 0.314      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -107       |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.75e+05   |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0271    |
# |    value_loss           | 7.46e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 61          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.026019827 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -107        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71e+05    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 7.48e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1336       |
# |    iterations           | 62         |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.02637947 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -106       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.74e+05   |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0257    |
# |    value_loss           | 7.53e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 63          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.024023585 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.79e+05    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 7.65e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1339        |
# |    iterations           | 64          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.025615748 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -106        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# ...
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.929       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 417          |
# |    n_updates            | 14780        |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 702          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 1480        |
# |    time_elapsed         | 2237        |
# |    total_timesteps      | 3031040     |
# | train/                  |             |
# |    approx_kl            | 0.004232364 |
# |    clip_fraction        | 0.0556      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 218         |
# |    n_updates            | 14790       |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 525         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1481         |
# |    time_elapsed         | 2239         |
# |    total_timesteps      | 3033088      |
# | train/                  |              |
# |    approx_kl            | 0.0048667686 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 363          |
# |    n_updates            | 14800        |
# |    policy_gradient_loss | -0.00596     |
# |    value_loss           | 638          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1482         |
# |    time_elapsed         | 2240         |
# |    total_timesteps      | 3035136      |
# | train/                  |              |
# |    approx_kl            | 0.0036795705 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.882       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 216          |
# |    n_updates            | 14810        |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 539          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 1483        |
# |    time_elapsed         | 2242        |
# |    total_timesteps      | 3037184     |
# | train/                  |             |
# |    approx_kl            | 0.003926317 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 294         |
# |    n_updates            | 14820       |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 635         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1484         |
# |    time_elapsed         | 2243         |
# |    total_timesteps      | 3039232      |
# | train/                  |              |
# |    approx_kl            | 0.0031801027 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.809       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 238          |
# |    n_updates            | 14830        |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 594          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 1485        |
# |    time_elapsed         | 2245        |
# |    total_timesteps      | 3041280     |
# | train/                  |             |
# |    approx_kl            | 0.003814417 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 357         |
# |    n_updates            | 14840       |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 560         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1486         |
# |    time_elapsed         | 2246         |
# |    total_timesteps      | 3043328      |
# | train/                  |              |
# |    approx_kl            | 0.0035344167 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.771       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 314          |
# |    n_updates            | 14850        |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 640          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1487         |
# |    time_elapsed         | 2248         |
# |    total_timesteps      | 3045376      |
# | train/                  |              |
# |    approx_kl            | 0.0038790207 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 238          |
# |    n_updates            | 14860        |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 506          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 1488        |
# |    time_elapsed         | 2249        |
# |    total_timesteps      | 3047424     |
# | train/                  |             |
# |    approx_kl            | 0.004130475 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 322         |
# |    n_updates            | 14870       |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 635         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1489         |
# |    time_elapsed         | 2251         |
# |    total_timesteps      | 3049472      |
# | train/                  |              |
# |    approx_kl            | 0.0034467427 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.708       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 227          |
# |    n_updates            | 14880        |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 529          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 1490        |
# |    time_elapsed         | 2252        |
# |    total_timesteps      | 3051520     |
# | train/                  |             |
# |    approx_kl            | 0.005951232 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 279         |
# |    n_updates            | 14890       |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 703         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1491         |
# |    time_elapsed         | 2254         |
# |    total_timesteps      | 3053568      |
# | train/                  |              |
# |    approx_kl            | 0.0034218049 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.681       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 393          |
# |    n_updates            | 14900        |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 597          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1492         |
# |    time_elapsed         | 2256         |
# |    total_timesteps      | 3055616      |
# | train/                  |              |
# |    approx_kl            | 0.0038223444 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 235          |
# |    n_updates            | 14910        |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 540          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1493         |
# |    time_elapsed         | 2257         |
# |    total_timesteps      | 3057664      |
# | train/                  |              |
# |    approx_kl            | 0.0050266804 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.667       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 373          |
# |    n_updates            | 14920        |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 734          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1494         |
# |    time_elapsed         | 2259         |
# |    total_timesteps      | 3059712      |
# | train/                  |              |
# |    approx_kl            | 0.0022830777 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 357          |
# |    n_updates            | 14930        |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 668          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1354         |
# |    iterations           | 1495         |
# |    time_elapsed         | 2260         |
# |    total_timesteps      | 3061760      |
# | train/                  |              |
# |    approx_kl            | 0.0045654164 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 295          |
# |    n_updates            | 14940        |
# |    policy_gradient_loss | -0.00464     |
# |    value_loss           | 604          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 63
#      60 model.set_logger(new_logger)
#      62 # 학습
# ---> 63 model.learn(total_timesteps=100000000)
#      65 # 로그 파일 경로 확인
#      66 print(f"Logs saved in directory: {log_dir}")
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:336, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     333         assert self.ep_info_buffer is not None
#     334         self._dump_logs(iteration)
# --> 336     self.train()
#     338 callback.on_training_end()
#     340 return self
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/ppo/ppo.py:275, in PPO.train(self)
#     273 # Optimization step
#     274 self.policy.optimizer.zero_grad()
# --> 275 loss.backward()
#     276 # Clip grad norm
#     277 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File /usr/local/lib/python3.8/dist-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
