# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from sb3_contrib import RecurrentPPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os

# 스마트 팩토리 환경 생성
class SmartFactoryEnvRNN(gym.Env):
    def __init__(self, n_machines=64, energy_limit=128):
        super(SmartFactoryEnvRNN, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간 (기계 상태 + 작동 시간)
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines * 2 + 1,), dtype=float
        )

        # 초기화
        self.state = None
        self.machine_runtime = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines * 2 + 1, dtype=float)
        self.machine_runtime = np.zeros(self.n_machines, dtype=float)
        return self.state, {}

    def step(self, action):
        # 기계 작동 시간 업데이트
        self.machine_runtime += action

        # 생산성 및 에너지 사용량 계산
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        productivity_factors = np.exp(-0.1 * self.machine_runtime)  # 작동 시간이 길수록 생산성 감소
        production = np.dot(np.random.uniform(1, 3, self.n_machines) * productivity_factors, action)

        # 페널티 계산
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        # 상태 업데이트 (현재 행동, 작동 시간, 에너지 사용량)
        self.state = np.concatenate([action, self.machine_runtime, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:self.n_machines]}, Runtime: {self.state[self.n_machines:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 64
env = DummyVecEnv([lambda: SmartFactoryEnvRNN(n_machines=n_machines, energy_limit=128)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_rnn_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# RecurrentPPO 모델 생성
model = RecurrentPPO(
    "MlpLstmPolicy",  # LSTM 기반 정책
    env,
    verbose=1,
    n_steps=512,  # RNN 훈련에 필요한 적절한 step 설정
    batch_size=64,  # batch size를 줄여 메모리 사용량 감소
    gae_lambda=0.95,
    gamma=0.99,
    tensorboard_log=log_dir,
)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=1000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_rnn_binary_64/
# Using cuda device
# -----------------------------
# | time/              |      |
# |    fps             | 1125 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 512  |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.012177447 |
# |    clip_fraction        | 0.0574      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.4       |
# |    explained_variance   | 6.9e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.99e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 5.74e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.015599353 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.3       |
# |    explained_variance   | 2.26e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 6.01e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.017677672 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 5.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.018725693 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3e+05       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 5.75e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 587        |
# |    iterations           | 6          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.01895405 |
# |    clip_fraction        | 0.139      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.2      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.9e+05    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0379    |
# |    value_loss           | 5.65e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 584         |
# |    iterations           | 7           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.016008068 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.1       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0333     |
# |    value_loss           | 5.34e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 8           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019973695 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 5.28e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 591         |
# |    iterations           | 9           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.020808285 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+05    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 5.06e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 10          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.015540959 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0324     |
# |    value_loss           | 4.85e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 11          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.019220866 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.36e+05    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 4.68e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 12          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024053007 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 4.51e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 13          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.021067096 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.2       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0379     |
# |    value_loss           | 4.24e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 14          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.023333889 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 4.01e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 15          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.028232297 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0472     |
# |    value_loss           | 3.86e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 16          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.024159119 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 3.87e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 17          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.021294465 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81e+05    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0413     |
# |    value_loss           | 3.59e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 18          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.022831356 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.69e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0426     |
# |    value_loss           | 3.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 19          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.024588866 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+05     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 3.26e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 20          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.024406841 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 3.06e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 576         |
# |    iterations           | 21          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.022306398 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.8       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 2.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 578         |
# |    iterations           | 22          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.026833612 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 2.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 23          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.026183773 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38e+05    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 2.66e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 24          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.027945101 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.5       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+05    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 2.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 25          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.025413027 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0401     |
# |    value_loss           | 2.33e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 568        |
# |    iterations           | 26         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.02898032 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -38.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15e+05   |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.05      |
# |    value_loss           | 2.25e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 27          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.031444877 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0495     |
# |    value_loss           | 2.11e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 570         |
# |    iterations           | 28          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.028205879 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 1.99e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 29          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.023063054 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.74e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 1.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 30          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.027900372 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.71e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 1.77e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 565         |
# |    iterations           | 31          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 15872       |
# | train/                  |             |
# |    approx_kl            | 0.027345004 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.97e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 1.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 32          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026549213 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.68e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 1.57e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 33          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 16896       |
# | train/                  |             |
# |    approx_kl            | 0.026133623 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.37e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 1.49e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 34          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.029793296 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.79e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0518     |
# |    value_loss           | 1.33e+05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 564       |
# |    iterations           | 35        |
# |    time_elapsed         | 31        |
# |    total_timesteps      | 17920     |
# | train/                  |           |
# |    approx_kl            | 0.0265962 |
# |    clip_fraction        | 0.307     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -33.6     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.58e+04  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0466   |
# |    value_loss           | 1.27e+05  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 36          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.035081778 |
# |    clip_fraction        | 0.348       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.9       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.66e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0506     |
# |    value_loss           | 1.14e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 37          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18944       |
# | train/                  |             |
# |    approx_kl            | 0.028414741 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.2       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.66e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 1.05e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 38          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.028557453 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.5       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.99e+04    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 9.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 39          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 19968       |
# | train/                  |             |
# |    approx_kl            | 0.028816082 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -30.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.38e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 9.05e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 40          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024512572 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -30.1       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.17e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 8.26e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 560        |
# |    iterations           | 41         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 20992      |
# | train/                  |            |
# |    approx_kl            | 0.03072811 |
# |    clip_fraction        | 0.347      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.55e+04   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0511    |
# |    value_loss           | 7.57e+04   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 42         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.02725846 |
# |    clip_fraction        | 0.325      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.55e+04   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.045     |
# |    value_loss           | 7.28e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 561         |
# |    iterations           | 43          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 22016       |
# | train/                  |             |
# |    approx_kl            | 0.030870616 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28         |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.48e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 6.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 562         |
# |    iterations           | 44          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.031285524 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 5.77e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 560         |
# |    iterations           | 45          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.030511197 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 5.54e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 561        |
# |    iterations           | 46         |
# |    time_elapsed         | 41         |
# |    total_timesteps      | 23552      |
# | train/                  |            |
# |    approx_kl            | 0.02927147 |
# |    clip_fraction        | 0.315      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25.8      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.24e+04   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.043     |
# |    value_loss           | 4.97e+04   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 562        |
# |    iterations           | 47         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 24064      |
# | train/                  |            |
# |    approx_kl            | 0.02609833 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -25        |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.57e+04   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.046     |
# |    value_loss           | 4.68e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 563         |
# |    iterations           | 48          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.028608553 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11e+04    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 3.95e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 565        |
# |    iterations           | 49         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 25088      |
# | train/                  |            |
# |    approx_kl            | 0.02949858 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.5      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.84e+04   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0449    |
# |    value_loss           | 3.39e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 50          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.028910333 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 3.38e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 567         |
# |    iterations           | 51          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 26112       |
# | train/                  |             |
# |    approx_kl            | 0.029839134 |
# |    clip_fraction        | 0.343       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+04     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0456     |
# |    value_loss           | 2.73e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 52          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.028407626 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21         |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0506     |
# |    value_loss           | 2.6e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 53          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 27136       |
# | train/                  |             |
# |    approx_kl            | 0.028111372 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0412     |
# |    value_loss           | 2.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 54          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.024798226 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.4       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0393     |
# |    value_loss           | 1.89e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 569         |
# |    iterations           | 55          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.037934467 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.5       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.51e+03    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0526     |
# |    value_loss           | 1.7e+04     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 570        |
# |    iterations           | 56         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.03318008 |
# |    clip_fraction        | 0.359      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -17.6      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.59e+03   |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0523    |
# |    value_loss           | 1.48e+04   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 571        |
# |    iterations           | 57         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 29184      |
# | train/                  |            |
# |    approx_kl            | 0.03445138 |
# |    clip_fraction        | 0.358      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -16.8      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.12e+03   |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.0525    |
# |    value_loss           | 1.29e+04   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 571        |
# |    iterations           | 58         |
# |    time_elapsed         | 51         |
# |    total_timesteps      | 29696      |
# | train/                  |            |
# |    approx_kl            | 0.03086728 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -16        |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.57e+03   |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0477    |
# |    value_loss           | 1.11e+04   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 572       |
# |    iterations           | 59        |
# |    time_elapsed         | 52        |
# |    total_timesteps      | 30208     |
# | train/                  |           |
# |    approx_kl            | 0.0319492 |
# |    clip_fraction        | 0.373     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -15.1     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.74e+03  |
# |    n_updates            | 580       |
# |    policy_gradient_loss | -0.0548   |
# |    value_loss           | 9.03e+03  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 60          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.034348994 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.79e+03    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 7.25e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 573         |
# |    iterations           | 61          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 31232       |
# | train/                  |             |
# |    approx_kl            | 0.031118672 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.6e+03     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0455     |
# |    value_loss           | 6.25e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 574         |
# |    iterations           | 62          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.031635717 |
# |    clip_fraction        | 0.335       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.68e+03    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0475     |
# |    value_loss           | 5.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 63          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 32256       |
# | train/                  |             |
# |    approx_kl            | 0.028297052 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+03    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 4.48e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 575        |
# |    iterations           | 64         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.04115592 |
# |    clip_fraction        | 0.367      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11.4      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.07e+03   |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.06      |
# |    value_loss           | 3.35e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 575         |
# |    iterations           | 65          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 33280       |
# | train/                  |             |
# |    approx_kl            | 0.033920996 |
# |    clip_fraction        | 0.394       |
# ...
# |    iterations           | 290           |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 148480        |
# | train/                  |               |
# |    approx_kl            | 0.00030476577 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0118       |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000211      |
# |    n_updates            | 2890          |
# |    policy_gradient_loss | -0.00511      |
# |    value_loss           | 0.037         |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 561       |
# |    iterations           | 291       |
# |    time_elapsed         | 265       |
# |    total_timesteps      | 148992    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0118   |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.69e-06  |
# |    n_updates            | 2900      |
# |    policy_gradient_loss | -0.000276 |
# |    value_loss           | 2.03e-05  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 292          |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 149504       |
# | train/                  |              |
# |    approx_kl            | 0.0011691521 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0116      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.208        |
# |    n_updates            | 2910         |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 0.0909       |
# ------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 561      |
# |    iterations           | 293      |
# |    time_elapsed         | 267      |
# |    total_timesteps      | 150016   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0116  |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 3.07e-09 |
# |    n_updates            | 2920     |
# |    policy_gradient_loss | -0.00063 |
# |    value_loss           | 1.62e-06 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 561          |
# |    iterations           | 294          |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 150528       |
# | train/                  |              |
# |    approx_kl            | 0.0005314037 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0113      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000113     |
# |    n_updates            | 2930         |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 0.0423       |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 561            |
# |    iterations           | 295            |
# |    time_elapsed         | 269            |
# |    total_timesteps      | 151040         |
# | train/                  |                |
# |    approx_kl            | 0.000105857616 |
# |    clip_fraction        | 0.00137        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.0112        |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.000247       |
# |    n_updates            | 2940           |
# |    policy_gradient_loss | -0.000691      |
# |    value_loss           | 0.0481         |
# --------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 560       |
# |    iterations           | 296       |
# |    time_elapsed         | 270       |
# |    total_timesteps      | 151552    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0112   |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.32e-06  |
# |    n_updates            | 2950      |
# |    policy_gradient_loss | -0.000688 |
# |    value_loss           | 5.35e-05  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 560       |
# |    iterations           | 297       |
# |    time_elapsed         | 271       |
# |    total_timesteps      | 152064    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0112   |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.2e-07   |
# |    n_updates            | 2960      |
# |    policy_gradient_loss | -0.000611 |
# |    value_loss           | 8.39e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 560       |
# |    iterations           | 298       |
# |    time_elapsed         | 272       |
# |    total_timesteps      | 152576    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0112   |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00971  |
# |    n_updates            | 2970      |
# |    policy_gradient_loss | -0.000627 |
# |    value_loss           | 5.49e-06  |
# ---------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 560      |
# |    iterations           | 299      |
# |    time_elapsed         | 273      |
# |    total_timesteps      | 153088   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0112  |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 5.58e-07 |
# |    n_updates            | 2980     |
# |    policy_gradient_loss | 0.000575 |
# |    value_loss           | 4.47e-06 |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 560      |
# |    iterations           | 300      |
# |    time_elapsed         | 273      |
# |    total_timesteps      | 153600   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0112  |
# |    explained_variance   | 1.19e-07 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 9.37e-09 |
# |    n_updates            | 2990     |
# |    policy_gradient_loss | -0.00113 |
# |    value_loss           | 2.76e-06 |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 560      |
# |    iterations           | 301      |
# |    time_elapsed         | 274      |
# |    total_timesteps      | 154112   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0112  |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.00689 |
# |    n_updates            | 3000     |
# |    policy_gradient_loss | 3.44e-05 |
# |    value_loss           | 1.75e-06 |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 560           |
# |    iterations           | 302           |
# |    time_elapsed         | 275           |
# |    total_timesteps      | 154624        |
# | train/                  |               |
# |    approx_kl            | 0.00027260964 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0111       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.44e-05      |
# |    n_updates            | 3010          |
# |    policy_gradient_loss | -0.00126      |
# |    value_loss           | 0.0399        |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 560           |
# |    iterations           | 303           |
# |    time_elapsed         | 276           |
# |    total_timesteps      | 155136        |
# | train/                  |               |
# |    approx_kl            | 0.00029650645 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.011        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000251      |
# |    n_updates            | 3020          |
# |    policy_gradient_loss | -0.00113      |
# |    value_loss           | 0.0357        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 560          |
# |    iterations           | 304          |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0002791735 |
# |    clip_fraction        | 0.00176      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0108      |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000332     |
# |    n_updates            | 3030         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 0.051        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 560           |
# |    iterations           | 305           |
# |    time_elapsed         | 278           |
# |    total_timesteps      | 156160        |
# | train/                  |               |
# |    approx_kl            | 0.00027773122 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0107       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0655        |
# |    n_updates            | 3040          |
# |    policy_gradient_loss | -0.00104      |
# |    value_loss           | 0.0582        |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 81
#      78 model.set_logger(new_logger)
#      80 # 학습
# ---> 81 model.learn(total_timesteps=1000000)
#      83 # 로그 파일 경로 확인
#      84 print(f"Logs saved in directory: {log_dir}")
#
# File /usr/local/lib/python3.8/dist-packages/sb3_contrib/ppo_recurrent/ppo_recurrent.py:450, in RecurrentPPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     441 def learn(
#     442     self: SelfRecurrentPPO,
#     443     total_timesteps: int,
#    (...)
#     448     progress_bar: bool = False,
#     449 ) -> SelfRecurrentPPO:
# --> 450     return super().learn(
#     451         total_timesteps=total_timesteps,
#     452         callback=callback,
#     453         log_interval=log_interval,
#     454         tb_log_name=tb_log_name,
#     455         reset_num_timesteps=reset_num_timesteps,
#     456         progress_bar=progress_bar,
#     457     )
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:334, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     332     if log_interval is not None and iteration % log_interval == 0:
#     333         assert self.ep_info_buffer is not None
# --> 334         self._dump_logs(iteration)
#     336     self.train()
#     338 callback.on_training_end()
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:297, in OnPolicyAlgorithm._dump_logs(self, iteration)
#     295 if len(self.ep_success_buffer) > 0:
#     296     self.logger.record("rollout/success_rate", safe_mean(self.ep_success_buffer))
# --> 297 self.logger.dump(step=self.num_timesteps)
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/logger.py:539, in Logger.dump(self, step)
#     537 for _format in self.output_formats:
#     538     if isinstance(_format, KVWriter):
# --> 539         _format.write(self.name_to_value, self.name_to_excluded, step)
#     541 self.name_to_value.clear()
#     542 self.name_to_count.clear()
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/logger.py:436, in TensorBoardOutputFormat.write(self, key_values, key_excluded, step)
#     433         self.writer.file_writer.add_summary(session_end_info)
#     435 # Flush the output to the file
# --> 436 self.writer.flush()
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/tensorboard/writer.py:1194, in SummaryWriter.flush(self)
#    1192     return
#    1193 for writer in self.all_writers.values():
# -> 1194     writer.flush()
#
# File /usr/local/lib/python3.8/dist-packages/torch/utils/tensorboard/writer.py:153, in FileWriter.flush(self)
#     147 def flush(self):
#     148     """Flushes the event file to disk.
#     149
#     150     Call this method to make sure that all pending events have been written to
#     151     disk.
#     152     """
# --> 153     self.event_writer.flush()
#
# File ~/.local/lib/python3.8/site-packages/tensorboard/summary/writer/event_file_writer.py:121, in EventFileWriter.flush(self)
#     115 def flush(self):
#     116     """Flushes the event file to disk.
#     117
#     118     Call this method to make sure that all pending events have been
#     119     written to disk.
#     120     """
# --> 121     self._async_writer.flush()
#
# File ~/.local/lib/python3.8/site-packages/tensorboard/summary/writer/event_file_writer.py:176, in _AsyncWriter.flush(self)
#     174 if self._closed:
#     175     raise IOError("Writer is closed")
# --> 176 self._byte_queue.join()
#     177 self._writer.flush()
#
# File /usr/lib/python3.8/queue.py:89, in Queue.join(self)
#      87 with self.all_tasks_done:
#      88     while self.unfinished_tasks:
# ---> 89         self.all_tasks_done.wait()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
