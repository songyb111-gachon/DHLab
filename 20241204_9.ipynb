# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=81, energy_limit=162):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 81  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=162)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_81/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2247 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1641        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017307058 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -56.1       |
# |    explained_variance   | 0.000488    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 1.09e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1571        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014782506 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -56.1       |
# |    explained_variance   | -3.7e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.69e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 1.15e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014052201 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -56.1       |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.56e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 1.14e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1523        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014143297 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -56         |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0243     |
# |    value_loss           | 1.17e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1504        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017744038 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -56         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.9e+04     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 1.18e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1483       |
# |    iterations           | 7          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01632475 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -55.9      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.94e+04   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0265    |
# |    value_loss           | 1.19e+05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1478         |
# |    iterations           | 8            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0151184155 |
# |    clip_fraction        | 0.233        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -55.9        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.04e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0268      |
# |    value_loss           | 1.21e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1469        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014433732 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.8       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.03e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 1.24e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1468        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014340907 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.96e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 1.23e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1464        |
# |    iterations           | 11          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013358942 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6e+04       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 1.25e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1465        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016446479 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.19e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 1.25e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1464        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012719249 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.07e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 1.29e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1459        |
# |    iterations           | 14          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015544916 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.25e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 1.28e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1458        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015119642 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.38e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 1.29e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1456        |
# |    iterations           | 16          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014622812 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.53e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 1.35e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1458        |
# |    iterations           | 17          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016524207 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -55.1       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.51e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 1.35e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1440       |
# |    iterations           | 18         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01362879 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -55        |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.69e+04   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.024     |
# |    value_loss           | 1.34e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1438        |
# |    iterations           | 19          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014972554 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -54.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.7e+04     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 1.39e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1436         |
# |    iterations           | 20           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0134531185 |
# |    clip_fraction        | 0.21         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -54.7        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.75e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0249      |
# |    value_loss           | 1.38e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1434        |
# |    iterations           | 21          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013304143 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -54.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.01e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 1.41e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 22          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.013967397 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -54.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.8e+04     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 1.41e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1433        |
# |    iterations           | 23          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015961133 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -54.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.81e+04    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 1.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1434        |
# |    iterations           | 24          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014421079 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -54.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0282     |
# |    value_loss           | 1.43e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 25          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014039522 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -54.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.16e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0243     |
# |    value_loss           | 1.45e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1426        |
# |    iterations           | 26          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015168101 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -53.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.99e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 1.42e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 27          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.016184887 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -53.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.34e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 1.48e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 28          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016176136 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -53.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.11e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 1.46e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1424        |
# |    iterations           | 29          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015426321 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -53.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.45e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 1.48e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1425        |
# |    iterations           | 30          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014629552 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -53.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.4e+04     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 1.51e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1418        |
# |    iterations           | 31          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.015693206 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -53         |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.28e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 1.5e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1419        |
# |    iterations           | 32          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.018290188 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52.8       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.57e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 1.53e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1419        |
# |    iterations           | 33          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016907506 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.75e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 1.56e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1419        |
# |    iterations           | 34          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015631698 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52.4       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 1.56e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1418        |
# |    iterations           | 35          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014032971 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -52.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 1.56e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1419        |
# |    iterations           | 36          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.018637026 |
# |    clip_fraction        | 0.261       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.88e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 1.62e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1416        |
# |    iterations           | 37          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.015745915 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.91e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 1.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1415        |
# |    iterations           | 38          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013138782 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.6       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.85e+04    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 1.59e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1415       |
# |    iterations           | 39         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01740841 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.01e+04   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0248    |
# |    value_loss           | 1.61e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1415        |
# |    iterations           | 40          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018925685 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.06e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 1.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1416        |
# |    iterations           | 41          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015234068 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -50.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.15e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 1.65e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1418        |
# |    iterations           | 42          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.016536672 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -50.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.34e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 1.67e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1414       |
# |    iterations           | 43         |
# |    time_elapsed         | 62         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01649547 |
# |    clip_fraction        | 0.241      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -50.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.99e+04   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0219    |
# |    value_loss           | 1.69e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 44          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013251162 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -50.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.54e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 1.71e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 45          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.016337197 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -49.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.23e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 1.68e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1411        |
# |    iterations           | 46          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015096373 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -49.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2e+04     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 1.67e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1413        |
# |    iterations           | 47          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017372802 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -49.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 1.72e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1414       |
# |    iterations           | 48         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.01611036 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -49        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.58e+04   |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0223    |
# |    value_loss           | 1.73e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1407        |
# |    iterations           | 49          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.015479475 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -48.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.47e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 1.73e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1404       |
# |    iterations           | 50         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01812588 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -48.4      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.54e+04   |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0224    |
# |    value_loss           | 1.76e+05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1399         |
# |    iterations           | 51           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0135233775 |
# |    clip_fraction        | 0.209        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -48.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.88e+04     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0161      |
# |    value_loss           | 1.78e+05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1397       |
# |    iterations           | 52         |
# |    time_elapsed         | 76         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01686313 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -47.9      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.72e+04   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0199    |
# |    value_loss           | 1.79e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 53          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.021919735 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -47.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.12e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 1.82e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 54          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.016931579 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -47.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97e+04    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 1.83e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 55          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.016236734 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -46.8       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.18e+04    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 1.84e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 56          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.020358779 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -46.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.3e+04     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.025      |
# |    value_loss           | 1.86e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 57          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.016293773 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -46         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.36e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 1.87e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1400       |
# |    iterations           | 58         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.01918324 |
# |    clip_fraction        | 0.262      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -45.8      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.22e+04   |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0208    |
# |    value_loss           | 1.87e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 59          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.018941853 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.03e+04    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 1.9e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 60          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.016391901 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -45.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.42e+04    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 1.9e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1404        |
# |    iterations           | 61          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.017695468 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.8       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.35e+04    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 1.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 62          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.017762821 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.54e+04    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 1.95e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 63          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.018234834 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.66e+04    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 1.95e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1402        |
# |    iterations           | 64          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.015149253 |
# |    clip_fraction        | 0.207       |
# ...
# |    approx_kl            | 0.000567505 |
# |    clip_fraction        | 0.00684     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.174      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.3        |
# |    n_updates            | 9450        |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 280         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1348          |
# |    iterations           | 947           |
# |    time_elapsed         | 1438          |
# |    total_timesteps      | 1939456       |
# | train/                  |               |
# |    approx_kl            | 0.00073050696 |
# |    clip_fraction        | 0.00977       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.187        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 143           |
# |    n_updates            | 9460          |
# |    policy_gradient_loss | -0.000594     |
# |    value_loss           | 399           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 948          |
# |    time_elapsed         | 1439         |
# |    total_timesteps      | 1941504      |
# | train/                  |              |
# |    approx_kl            | 0.0008051543 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.199       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 139          |
# |    n_updates            | 9470         |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 251          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 949          |
# |    time_elapsed         | 1441         |
# |    total_timesteps      | 1943552      |
# | train/                  |              |
# |    approx_kl            | 0.0009724047 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.198       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 112          |
# |    n_updates            | 9480         |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 263          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1348          |
# |    iterations           | 950           |
# |    time_elapsed         | 1442          |
# |    total_timesteps      | 1945600       |
# | train/                  |               |
# |    approx_kl            | 0.00062018883 |
# |    clip_fraction        | 0.00581       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.195        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 111           |
# |    n_updates            | 9490          |
# |    policy_gradient_loss | -0.00123      |
# |    value_loss           | 266           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 951          |
# |    time_elapsed         | 1444         |
# |    total_timesteps      | 1947648      |
# | train/                  |              |
# |    approx_kl            | 0.0018327781 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.199       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 127          |
# |    n_updates            | 9500         |
# |    policy_gradient_loss | -0.000975    |
# |    value_loss           | 321          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 952          |
# |    time_elapsed         | 1446         |
# |    total_timesteps      | 1949696      |
# | train/                  |              |
# |    approx_kl            | 0.0009904958 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.197       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 9510         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 279          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1348        |
# |    iterations           | 953         |
# |    time_elapsed         | 1447        |
# |    total_timesteps      | 1951744     |
# | train/                  |             |
# |    approx_kl            | 0.000694305 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.198      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 9520        |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 235         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 954          |
# |    time_elapsed         | 1449         |
# |    total_timesteps      | 1953792      |
# | train/                  |              |
# |    approx_kl            | 0.0011424368 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.207       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 180          |
# |    n_updates            | 9530         |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 306          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 955          |
# |    time_elapsed         | 1450         |
# |    total_timesteps      | 1955840      |
# | train/                  |              |
# |    approx_kl            | 0.0008239013 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.209       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 9540         |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 279          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 956          |
# |    time_elapsed         | 1452         |
# |    total_timesteps      | 1957888      |
# | train/                  |              |
# |    approx_kl            | 0.0009979139 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.21        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 135          |
# |    n_updates            | 9550         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 307          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 957          |
# |    time_elapsed         | 1453         |
# |    total_timesteps      | 1959936      |
# | train/                  |              |
# |    approx_kl            | 0.0012316571 |
# |    clip_fraction        | 0.00698      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.2         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 168          |
# |    n_updates            | 9560         |
# |    policy_gradient_loss | -0.000751    |
# |    value_loss           | 306          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 958          |
# |    time_elapsed         | 1454         |
# |    total_timesteps      | 1961984      |
# | train/                  |              |
# |    approx_kl            | 0.0011364736 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 9570         |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 265          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 959          |
# |    time_elapsed         | 1456         |
# |    total_timesteps      | 1964032      |
# | train/                  |              |
# |    approx_kl            | 0.0009906709 |
# |    clip_fraction        | 0.0102       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.183       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 103          |
# |    n_updates            | 9580         |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 203          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 960          |
# |    time_elapsed         | 1458         |
# |    total_timesteps      | 1966080      |
# | train/                  |              |
# |    approx_kl            | 0.0008309146 |
# |    clip_fraction        | 0.00947      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.176       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 114          |
# |    n_updates            | 9590         |
# |    policy_gradient_loss | -0.000889    |
# |    value_loss           | 247          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 961          |
# |    time_elapsed         | 1459         |
# |    total_timesteps      | 1968128      |
# | train/                  |              |
# |    approx_kl            | 0.0009768946 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.175       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 193          |
# |    n_updates            | 9600         |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 286          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 962          |
# |    time_elapsed         | 1461         |
# |    total_timesteps      | 1970176      |
# | train/                  |              |
# |    approx_kl            | 0.0013678765 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.167       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 111          |
# |    n_updates            | 9610         |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 327          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1348        |
# |    iterations           | 963         |
# |    time_elapsed         | 1463        |
# |    total_timesteps      | 1972224     |
# | train/                  |             |
# |    approx_kl            | 0.001508917 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 200         |
# |    n_updates            | 9620        |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 340         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 964          |
# |    time_elapsed         | 1464         |
# |    total_timesteps      | 1974272      |
# | train/                  |              |
# |    approx_kl            | 0.0005436807 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 198          |
# |    n_updates            | 9630         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 380          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1347          |
# |    iterations           | 965           |
# |    time_elapsed         | 1466          |
# |    total_timesteps      | 1976320       |
# | train/                  |               |
# |    approx_kl            | 0.00043905812 |
# |    clip_fraction        | 0.00381       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.149        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 154           |
# |    n_updates            | 9640          |
# |    policy_gradient_loss | -0.000644     |
# |    value_loss           | 327           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1347         |
# |    iterations           | 966          |
# |    time_elapsed         | 1467         |
# |    total_timesteps      | 1978368      |
# | train/                  |              |
# |    approx_kl            | 0.0005822167 |
# |    clip_fraction        | 0.0114       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.147       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 9650         |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 301          |
# ------------------------------------------

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
