# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=144, energy_limit=288):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 144  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=288)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_144/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1273 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.024415977 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.8       |
# |    explained_variance   | 0.000148    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 3.52e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024963947 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.8       |
# |    explained_variance   | 1.55e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+05    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 3.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.023137031 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0294     |
# |    value_loss           | 3.68e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020162668 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0266     |
# |    value_loss           | 3.76e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 794         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021698218 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0243     |
# |    value_loss           | 3.77e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023519393 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.5       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0293     |
# |    value_loss           | 3.74e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.021672193 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.5       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 3.82e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022840455 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+05    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 3.83e+05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 779       |
# |    iterations           | 10        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0180842 |
# |    clip_fraction        | 0.266     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -99.4     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.93e+05  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.0267   |
# |    value_loss           | 3.91e+05  |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 777        |
# |    iterations           | 11         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01998812 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -99.3      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.91e+05   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0284    |
# |    value_loss           | 3.91e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.019493965 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 3.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 13          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.022730077 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99.1       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+05     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0281     |
# |    value_loss           | 3.9e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021322131 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 3.95e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 15          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021003107 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -99         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2e+05       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 4.03e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 773        |
# |    iterations           | 16         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02336847 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -98.9      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.01e+05   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0295    |
# |    value_loss           | 4.06e+05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 775        |
# |    iterations           | 17         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02086105 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -98.8      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.03e+05   |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0275    |
# |    value_loss           | 4.09e+05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 772        |
# |    iterations           | 18         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02086777 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -98.6      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.06e+05   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0286    |
# |    value_loss           | 4.17e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 19          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022136893 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -98.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1e+05     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 4.14e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 20          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019569026 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -98.3       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+05    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 4.24e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 21          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.019664505 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -98.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0265     |
# |    value_loss           | 4.26e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 22          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.025014445 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -98.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 4.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 23          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.024635948 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -98         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1e+05     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 4.29e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 24          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025458388 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -97.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.17e+05    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 4.35e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 25          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.021344535 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -97.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 4.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 26          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.019676559 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -97.5       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 4.42e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 27          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.020077385 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -97.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.19e+05    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 4.44e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 28          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.025121097 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -97.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.2e+05     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 4.42e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 29          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.018501095 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -96.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3e+05     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 4.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 30          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.020965405 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -96.8       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27e+05    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 4.57e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 31          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.022282755 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -96.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.28e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 4.59e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 32          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.021654151 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -96.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3e+05     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0264     |
# |    value_loss           | 4.7e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 33          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.021804001 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -96.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 4.71e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 34          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022311777 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -95.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 4.74e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 770        |
# |    iterations           | 35         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.01991912 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -95.8      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.42e+05   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.022     |
# |    value_loss           | 4.82e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 36          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.021070413 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -95.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0239     |
# |    value_loss           | 4.79e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 37          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022938028 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -95.4       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37e+05    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 4.84e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 38          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.021761414 |
# |    clip_fraction        | 0.286       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -95.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.41e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0263     |
# |    value_loss           | 4.83e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 772        |
# |    iterations           | 39         |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02163214 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -95        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.34e+05   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0254    |
# |    value_loss           | 4.83e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 40          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.021897573 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -94.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.46e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 4.91e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 41          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.021822777 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -94.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 4.93e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 42          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.023692707 |
# |    clip_fraction        | 0.308       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -94.2       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+05     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 5e+05       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 43          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.022087168 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -94         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.55e+05    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 5.11e+05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 771       |
# |    iterations           | 44        |
# |    time_elapsed         | 116       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0240768 |
# |    clip_fraction        | 0.294     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -93.7     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.57e+05  |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.0238   |
# |    value_loss           | 5.15e+05  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 45          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.021726536 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 5.07e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 772        |
# |    iterations           | 46         |
# |    time_elapsed         | 121        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.02368347 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -93.2      |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.57e+05   |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0272    |
# |    value_loss           | 5.18e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 47          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.021110108 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -93         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 5.18e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 48          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022333663 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.8       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62e+05    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 5.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 49          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019522998 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 5.23e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 50          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.021274284 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6e+05     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 5.29e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 51          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.024631113 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -92.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57e+05    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 5.36e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 52          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.024248868 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -91.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65e+05    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 5.27e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 772        |
# |    iterations           | 53         |
# |    time_elapsed         | 140        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.02419442 |
# |    clip_fraction        | 0.296      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -91.4      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.67e+05   |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0255    |
# |    value_loss           | 5.39e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 54          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.023236752 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -91.1       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64e+05    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 5.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 55          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.022146638 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -90.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67e+05    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 5.43e+05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 772       |
# |    iterations           | 56        |
# |    time_elapsed         | 148       |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0211519 |
# |    clip_fraction        | 0.276     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -90.5     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.71e+05  |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0205   |
# |    value_loss           | 5.47e+05  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 57          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.023980848 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -90.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73e+05    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 5.46e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 58          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.020331264 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -89.9       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73e+05    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 5.56e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 59          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.024989106 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -89.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.82e+05    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 5.61e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 60          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.030210242 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -89.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78e+05    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 5.64e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 61          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.022599407 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8e+05     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 5.7e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 62          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.020270912 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88.5       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.88e+05    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 5.76e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 63          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.022300974 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -88.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.91e+05    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 5.8e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 64          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.025570368 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -87.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# ...
# |    time_elapsed         | 3264         |
# |    total_timesteps      | 2519040      |
# | train/                  |              |
# |    approx_kl            | 0.0038650718 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 277          |
# |    n_updates            | 12290        |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 536          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 1231        |
# |    time_elapsed         | 3267        |
# |    total_timesteps      | 2521088     |
# | train/                  |             |
# |    approx_kl            | 0.003219218 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 260         |
# |    n_updates            | 12300       |
# |    policy_gradient_loss | -0.00294    |
# |    value_loss           | 563         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1232         |
# |    time_elapsed         | 3270         |
# |    total_timesteps      | 2523136      |
# | train/                  |              |
# |    approx_kl            | 0.0047692796 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.783       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 264          |
# |    n_updates            | 12310        |
# |    policy_gradient_loss | -0.00459     |
# |    value_loss           | 555          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1233         |
# |    time_elapsed         | 3272         |
# |    total_timesteps      | 2525184      |
# | train/                  |              |
# |    approx_kl            | 0.0049822973 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.792       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 335          |
# |    n_updates            | 12320        |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 555          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 1234        |
# |    time_elapsed         | 3275        |
# |    total_timesteps      | 2527232     |
# | train/                  |             |
# |    approx_kl            | 0.004174722 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 12330       |
# |    policy_gradient_loss | -0.00473    |
# |    value_loss           | 403         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1235         |
# |    time_elapsed         | 3278         |
# |    total_timesteps      | 2529280      |
# | train/                  |              |
# |    approx_kl            | 0.0032203188 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 283          |
# |    n_updates            | 12340        |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 672          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1236         |
# |    time_elapsed         | 3280         |
# |    total_timesteps      | 2531328      |
# | train/                  |              |
# |    approx_kl            | 0.0036344565 |
# |    clip_fraction        | 0.0515       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 153          |
# |    n_updates            | 12350        |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 504          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1237         |
# |    time_elapsed         | 3283         |
# |    total_timesteps      | 2533376      |
# | train/                  |              |
# |    approx_kl            | 0.0033331378 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 301          |
# |    n_updates            | 12360        |
# |    policy_gradient_loss | -0.00468     |
# |    value_loss           | 557          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1238         |
# |    time_elapsed         | 3286         |
# |    total_timesteps      | 2535424      |
# | train/                  |              |
# |    approx_kl            | 0.0037459116 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 12370        |
# |    policy_gradient_loss | -0.00386     |
# |    value_loss           | 570          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 1239        |
# |    time_elapsed         | 3289        |
# |    total_timesteps      | 2537472     |
# | train/                  |             |
# |    approx_kl            | 0.004403131 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 284         |
# |    n_updates            | 12380       |
# |    policy_gradient_loss | -0.00406    |
# |    value_loss           | 523         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1240         |
# |    time_elapsed         | 3291         |
# |    total_timesteps      | 2539520      |
# | train/                  |              |
# |    approx_kl            | 0.0032556339 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.789       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 12390        |
# |    policy_gradient_loss | -0.00444     |
# |    value_loss           | 429          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1241         |
# |    time_elapsed         | 3294         |
# |    total_timesteps      | 2541568      |
# | train/                  |              |
# |    approx_kl            | 0.0038976048 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 300          |
# |    n_updates            | 12400        |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 517          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 1242         |
# |    time_elapsed         | 3296         |
# |    total_timesteps      | 2543616      |
# | train/                  |              |
# |    approx_kl            | 0.0052149706 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 250          |
# |    n_updates            | 12410        |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 507          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 1243        |
# |    time_elapsed         | 3299        |
# |    total_timesteps      | 2545664     |
# | train/                  |             |
# |    approx_kl            | 0.003405843 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 212         |
# |    n_updates            | 12420       |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 537         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 1244        |
# |    time_elapsed         | 3302        |
# |    total_timesteps      | 2547712     |
# | train/                  |             |
# |    approx_kl            | 0.003227952 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 210         |
# |    n_updates            | 12430       |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 439         |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 63
#      60 model.set_logger(new_logger)
#      62 # 학습
# ---> 63 model.learn(total_timesteps=100000000)
#      65 # 로그 파일 경로 확인
#      66 print(f"Logs saved in directory: {log_dir}")
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/policies.py:655, in ActorCriticPolicy.forward(self, obs, deterministic)
#     653 values = self.value_net(latent_vf)
#     654 distribution = self._get_action_dist_from_latent(latent_pi)
# --> 655 actions = distribution.get_actions(deterministic=deterministic)
#     656 log_prob = distribution.log_prob(actions)
#     657 actions = actions.reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/distributions.py:89, in Distribution.get_actions(self, deterministic)
#      87 if deterministic:
#      88     return self.mode()
# ---> 89 return self.sample()
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/distributions.py:405, in BernoulliDistribution.sample(self)
#     404 def sample(self) -> th.Tensor:
# --> 405     return self.distribution.sample()
#
# File /usr/local/lib/python3.8/dist-packages/torch/distributions/bernoulli.py:105, in Bernoulli.sample(self, sample_shape)
#     103 def sample(self, sample_shape=torch.Size()):
#     104     shape = self._extended_shape(sample_shape)
# --> 105     with torch.no_grad():
#     106         return torch.bernoulli(self.probs.expand(shape))
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py:82, in no_grad.__enter__(self)
#      80 def __enter__(self) -> None:
#      81     self.prev = torch.is_grad_enabled()
# ---> 82     torch.set_grad_enabled(False)
#
# File /usr/local/lib/python3.8/dist-packages/torch/autograd/grad_mode.py:186, in set_grad_enabled.__init__(self, mode)
#     184 def __init__(self, mode: bool) -> None:
#     185     self.prev = torch.is_grad_enabled()
# --> 186     self.mode = mode
#     187     torch._C._set_grad_enabled(mode)
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
