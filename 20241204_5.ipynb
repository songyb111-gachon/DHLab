# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=49, energy_limit=98):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 49  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=98)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_49/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1313 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 905         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012304819 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34         |
# |    explained_variance   | 0.000148    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 3.86e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013146187 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.9       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2e+04       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 4.12e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 846         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013537442 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.9       |
# |    explained_variance   | -2.86e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.04e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 4.15e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012582301 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.8       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0286     |
# |    value_loss           | 4.21e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012263574 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.8       |
# |    explained_variance   | 7.15e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 4.3e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012390304 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.7       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.15e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 4.49e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011704499 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.7       |
# |    explained_variance   | -5.96e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.21e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 4.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 9           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011290241 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.6       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 4.51e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010859452 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.26e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 4.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010912739 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.5       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 4.49e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 12          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012461121 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.3e+04     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0302     |
# |    value_loss           | 4.71e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 13          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012791717 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.3       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 4.7e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 14          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011927799 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 4.86e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 15          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013038786 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.46e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 5.04e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 16          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009869454 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.9       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 5.12e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 17          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011360661 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.8       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+04     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 5.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 18          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010151877 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 5.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 19          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014498991 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.57e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 5.2e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 20          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012492498 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.3       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.65e+04    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 5.39e+04    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 807       |
# |    iterations           | 21        |
# |    time_elapsed         | 53        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0119645 |
# |    clip_fraction        | 0.207     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -32.1     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.65e+04  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.0266   |
# |    value_loss           | 5.43e+04  |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011070623 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32         |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.69e+04    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 5.45e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 808        |
# |    iterations           | 23         |
# |    time_elapsed         | 58         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01373199 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -31.8      |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.75e+04   |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0307    |
# |    value_loss           | 5.44e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012719287 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.74e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0275     |
# |    value_loss           | 5.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 25          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011940772 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.5       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7e+04     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 5.59e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 26          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012895291 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.2       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 5.81e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 27          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013476568 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.77e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 5.8e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 28          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012717236 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -30.8       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 5.8e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 29          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011224996 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -30.6       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 5.91e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 30          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011975586 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -30.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 6.02e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 31          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012263956 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -30.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.95e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 6.07e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 32          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012673975 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.9       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 6.11e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 33          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011934156 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.08e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 6.21e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 34          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011909692 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 6.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 35          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013519963 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.06e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 6.38e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 36          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.011288251 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.96e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 6.34e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 37          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.013189525 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.7       |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.04e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 6.32e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 802        |
# |    iterations           | 38         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01367495 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -28.5      |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.99e+04   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0231    |
# |    value_loss           | 6.47e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 39          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010348866 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -28.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2e+04     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 6.55e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 40          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013269805 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 6.47e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 801         |
# |    iterations           | 41          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011555058 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.23e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 6.54e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 802         |
# |    iterations           | 42          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.012634505 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 6.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 43          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013528492 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.33e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 6.76e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 44          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011353755 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -27         |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 6.68e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 45           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0120677985 |
# |    clip_fraction        | 0.186        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -26.7        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0183      |
# |    value_loss           | 6.8e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 46          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011884931 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.43e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 7e+04       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 47          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010947145 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.34e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 6.87e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 48          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011309597 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -26         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41e+04    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 6.93e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 49          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011338338 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.38e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 6.82e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 50          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.014844043 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 6.79e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 51          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.013783567 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -25.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.37e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 7.03e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 797        |
# |    iterations           | 52         |
# |    time_elapsed         | 133        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.01377254 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.9      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.42e+04   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0191    |
# |    value_loss           | 6.94e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 53          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.012168922 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.49e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 7.03e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 54           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0115500465 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -24.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.35e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0183      |
# |    value_loss           | 6.95e+04     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 796        |
# |    iterations           | 55         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.01204475 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.1      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.31e+04   |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0192    |
# |    value_loss           | 7.02e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 56          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012410092 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.51e+04    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 7.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 57          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.014250755 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 7.11e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 58          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.011756649 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.55e+04    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 7.34e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 59          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.015096642 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.5e+04     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 7.24e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 60          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.012701677 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.6e+04     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 7.23e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 61          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.011252664 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.4       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.64e+04    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 7.29e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 62          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.012194756 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.54e+04    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 7.25e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 796        |
# |    iterations           | 63         |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.01213134 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -21.9      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.65e+04   |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0166    |
# |    value_loss           | 7.38e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 64          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.011932708 |
# |    clip_fraction        | 0.158       |
# ...
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 62.4          |
# |    n_updates            | 5420          |
# |    policy_gradient_loss | -0.000756     |
# |    value_loss           | 132           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 544           |
# |    time_elapsed         | 1399          |
# |    total_timesteps      | 1114112       |
# | train/                  |               |
# |    approx_kl            | 0.00070563867 |
# |    clip_fraction        | 0.0124        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.112        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 77.4          |
# |    n_updates            | 5430          |
# |    policy_gradient_loss | -0.000797     |
# |    value_loss           | 161           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 545          |
# |    time_elapsed         | 1402         |
# |    total_timesteps      | 1116160      |
# | train/                  |              |
# |    approx_kl            | 0.0005456868 |
# |    clip_fraction        | 0.00752      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.111       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91           |
# |    n_updates            | 5440         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 204          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 546          |
# |    time_elapsed         | 1405         |
# |    total_timesteps      | 1118208      |
# | train/                  |              |
# |    approx_kl            | 0.0005223278 |
# |    clip_fraction        | 0.00796      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.117       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.6         |
# |    n_updates            | 5450         |
# |    policy_gradient_loss | -0.000862    |
# |    value_loss           | 162          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 547           |
# |    time_elapsed         | 1407          |
# |    total_timesteps      | 1120256       |
# | train/                  |               |
# |    approx_kl            | 0.00062967837 |
# |    clip_fraction        | 0.00811       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.108        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 100           |
# |    n_updates            | 5460          |
# |    policy_gradient_loss | -0.00109      |
# |    value_loss           | 177           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 548           |
# |    time_elapsed         | 1410          |
# |    total_timesteps      | 1122304       |
# | train/                  |               |
# |    approx_kl            | 0.00030281497 |
# |    clip_fraction        | 0.00269       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.102        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 62.8          |
# |    n_updates            | 5470          |
# |    policy_gradient_loss | -0.000508     |
# |    value_loss           | 150           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 549           |
# |    time_elapsed         | 1412          |
# |    total_timesteps      | 1124352       |
# | train/                  |               |
# |    approx_kl            | 0.00025587267 |
# |    clip_fraction        | 0.00288       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0913       |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 61.8          |
# |    n_updates            | 5480          |
# |    policy_gradient_loss | -0.000463     |
# |    value_loss           | 181           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 550           |
# |    time_elapsed         | 1415          |
# |    total_timesteps      | 1126400       |
# | train/                  |               |
# |    approx_kl            | 0.00027894473 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0969       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 126           |
# |    n_updates            | 5490          |
# |    policy_gradient_loss | -0.000579     |
# |    value_loss           | 205           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 551          |
# |    time_elapsed         | 1417         |
# |    total_timesteps      | 1128448      |
# | train/                  |              |
# |    approx_kl            | 0.0007381779 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.101       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 91.6         |
# |    n_updates            | 5500         |
# |    policy_gradient_loss | -0.00068     |
# |    value_loss           | 163          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 552           |
# |    time_elapsed         | 1420          |
# |    total_timesteps      | 1130496       |
# | train/                  |               |
# |    approx_kl            | 0.00024639594 |
# |    clip_fraction        | 0.00474       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.097        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 91.2          |
# |    n_updates            | 5510          |
# |    policy_gradient_loss | -0.000555     |
# |    value_loss           | 169           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 553         |
# |    time_elapsed         | 1422        |
# |    total_timesteps      | 1132544     |
# | train/                  |             |
# |    approx_kl            | 0.000321427 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.107      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.1        |
# |    n_updates            | 5520        |
# |    policy_gradient_loss | -0.000239   |
# |    value_loss           | 160         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 554           |
# |    time_elapsed         | 1425          |
# |    total_timesteps      | 1134592       |
# | train/                  |               |
# |    approx_kl            | 0.00011195433 |
# |    clip_fraction        | 0.00151       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.105        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 130           |
# |    n_updates            | 5530          |
# |    policy_gradient_loss | -0.000367     |
# |    value_loss           | 207           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 555          |
# |    time_elapsed         | 1428         |
# |    total_timesteps      | 1136640      |
# | train/                  |              |
# |    approx_kl            | 0.0003789162 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.105       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.3         |
# |    n_updates            | 5540         |
# |    policy_gradient_loss | -0.000214    |
# |    value_loss           | 164          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 556          |
# |    time_elapsed         | 1430         |
# |    total_timesteps      | 1138688      |
# | train/                  |              |
# |    approx_kl            | 0.0003498447 |
# |    clip_fraction        | 0.00562      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0971      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 5550         |
# |    policy_gradient_loss | -0.000563    |
# |    value_loss           | 189          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 557           |
# |    time_elapsed         | 1433          |
# |    total_timesteps      | 1140736       |
# | train/                  |               |
# |    approx_kl            | 0.00037627592 |
# |    clip_fraction        | 0.00557       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0962       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 83.4          |
# |    n_updates            | 5560          |
# |    policy_gradient_loss | -0.000843     |
# |    value_loss           | 158           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 558           |
# |    time_elapsed         | 1436          |
# |    total_timesteps      | 1142784       |
# | train/                  |               |
# |    approx_kl            | 0.00017723802 |
# |    clip_fraction        | 0.00391       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.102        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 80.1          |
# |    n_updates            | 5570          |
# |    policy_gradient_loss | -0.000447     |
# |    value_loss           | 176           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 559           |
# |    time_elapsed         | 1438          |
# |    total_timesteps      | 1144832       |
# | train/                  |               |
# |    approx_kl            | 0.00046597375 |
# |    clip_fraction        | 0.00645       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0989       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 74.2          |
# |    n_updates            | 5580          |
# |    policy_gradient_loss | -0.00071      |
# |    value_loss           | 180           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 560           |
# |    time_elapsed         | 1441          |
# |    total_timesteps      | 1146880       |
# | train/                  |               |
# |    approx_kl            | 0.00045800343 |
# |    clip_fraction        | 0.00566       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.097        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 70.1          |
# |    n_updates            | 5590          |
# |    policy_gradient_loss | -0.000236     |
# |    value_loss           | 161           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 795           |
# |    iterations           | 561           |
# |    time_elapsed         | 1444          |
# |    total_timesteps      | 1148928       |
# | train/                  |               |
# |    approx_kl            | 0.00050769834 |
# |    clip_fraction        | 0.00532       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0918       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 105           |
# |    n_updates            | 5600          |
# |    policy_gradient_loss | -0.000689     |
# |    value_loss           | 173           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 562          |
# |    time_elapsed         | 1446         |
# |    total_timesteps      | 1150976      |
# | train/                  |              |
# |    approx_kl            | 0.0010048413 |
# |    clip_fraction        | 0.00522      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0879      |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.5         |
# |    n_updates            | 5610         |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 563          |
# |    time_elapsed         | 1449         |
# |    total_timesteps      | 1153024      |
# | train/                  |              |
# |    approx_kl            | 0.0003839726 |
# |    clip_fraction        | 0.00542      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.077       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 5620         |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 196          |
# ------------------------------------------

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
