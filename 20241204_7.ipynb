# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=64, energy_limit=128):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 64  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=128)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_64/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 1355 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016587792 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.3       |
# |    explained_variance   | 8.11e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 6.7e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016590897 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.3       |
# |    explained_variance   | 1.73e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.49e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 7.05e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 875         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014787007 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.3       |
# |    explained_variance   | -1.31e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.47e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 7.22e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013932669 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.2       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.53e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 7.32e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013262581 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.2       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.56e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 7.31e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 7          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01570504 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -44.1      |
# |    explained_variance   | 6.56e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.73e+04   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.027     |
# |    value_loss           | 7.54e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 8           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012913014 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44.1       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 7.55e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015401336 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -44         |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.76e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 7.64e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 10          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015663605 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.97e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 7.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.016777255 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.88e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 8.01e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 12          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015283413 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 8.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 13          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015931237 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.94e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 8.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 14          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015668541 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.02e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 8.42e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 845         |
# |    iterations           | 15          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014727965 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.14e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 8.59e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 16          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012229223 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43.1       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.24e+04    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 8.69e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 17          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013769076 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -43         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.41e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 8.85e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 18          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013056315 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.26e+04    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 8.84e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 19          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013563057 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.32e+04    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 9.06e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 20          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012443345 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.34e+04    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 8.83e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 843         |
# |    iterations           | 21          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014169172 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.61e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 9.33e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 842        |
# |    iterations           | 22         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.01632557 |
# |    clip_fraction        | 0.243      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.1      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.68e+04   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0248    |
# |    value_loss           | 9.31e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 23          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014003385 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.73e+04    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 9.5e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 842         |
# |    iterations           | 24          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015044626 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.74e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0254     |
# |    value_loss           | 9.57e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 25          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013358828 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.92e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 9.84e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 26          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015578678 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.62e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 9.7e+04     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 839        |
# |    iterations           | 27         |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01253669 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.65e+04   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0199    |
# |    value_loss           | 9.79e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 28          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012809014 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.85e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 9.83e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 29          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016098373 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.88e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 9.98e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 30          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012089197 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.6       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.98e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 1.02e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 31           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0122680655 |
# |    clip_fraction        | 0.195        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -40.5        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.16e+04     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.019       |
# |    value_loss           | 1.03e+05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 836        |
# |    iterations           | 32         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01169298 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -40.3      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.18e+04   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0186    |
# |    value_loss           | 1.05e+05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 836        |
# |    iterations           | 33         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01490061 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -40.1      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.13e+04   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.022     |
# |    value_loss           | 1.03e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 34          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.018648267 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.22e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 1.06e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 35          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014969257 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.6       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.27e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 1.06e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 36          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.014555296 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.23e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 1.06e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 835        |
# |    iterations           | 37         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01516496 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -39        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.38e+04   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0212    |
# |    value_loss           | 1.09e+05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 835        |
# |    iterations           | 38         |
# |    time_elapsed         | 93         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01369356 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -38.8      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.51e+04   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.017     |
# |    value_loss           | 1.12e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 835         |
# |    iterations           | 39          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.016245198 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.33e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 1.09e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 40          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015848175 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 1.13e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 41          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.014204953 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.48e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 1.12e+05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 834        |
# |    iterations           | 42         |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.01572592 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.9      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.56e+04   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0197    |
# |    value_loss           | 1.13e+05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 43          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.014746053 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.7e+04     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 1.16e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 44          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.013866315 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.85e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 1.17e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 45          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.016486824 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.71e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 1.16e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 46          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015193582 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.74e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 1.18e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 47          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017409177 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.91e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 1.2e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 48          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017197905 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.8       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.89e+04    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 1.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 49          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.013202505 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.5       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.77e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 1.18e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 50          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.015697733 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.68e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 1.2e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 51          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.014118385 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.03e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0152     |
# |    value_loss           | 1.22e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 52          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017609995 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.98e+04    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 1.24e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 53          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.014222185 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.1e+04     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 1.23e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 830          |
# |    iterations           | 54           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0146954665 |
# |    clip_fraction        | 0.225        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -33.8        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.13e+04     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0181      |
# |    value_loss           | 1.25e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 55          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.014705095 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.7       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.14e+04    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 1.26e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 56          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.015002149 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33e+04    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 1.27e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 57          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.015453432 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.01e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 1.25e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 58          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.015187042 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44e+04    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 1.28e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 59          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.013217352 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.14e+04    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 1.27e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 60          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.011623463 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.32e+04    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 1.28e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 830         |
# |    iterations           | 61          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.013343188 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.52e+04    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 1.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 62          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.015097646 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.5       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.23e+04    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 1.29e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 63          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.014494335 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -31.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.35e+04    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 1.29e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 828         |
# |    iterations           | 64          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.014425713 |
# |    clip_fraction        | 0.235       |
# ...
# |    fps                  | 816          |
# |    iterations           | 599          |
# |    time_elapsed         | 1503         |
# |    total_timesteps      | 1226752      |
# | train/                  |              |
# |    approx_kl            | 0.0006456343 |
# |    clip_fraction        | 0.00693      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 5980         |
# |    policy_gradient_loss | -0.000814    |
# |    value_loss           | 261          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 600           |
# |    time_elapsed         | 1505          |
# |    total_timesteps      | 1228800       |
# | train/                  |               |
# |    approx_kl            | 0.00042521735 |
# |    clip_fraction        | 0.004         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.151        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 142           |
# |    n_updates            | 5990          |
# |    policy_gradient_loss | -0.000869     |
# |    value_loss           | 289           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 601           |
# |    time_elapsed         | 1508          |
# |    total_timesteps      | 1230848       |
# | train/                  |               |
# |    approx_kl            | 0.00083481247 |
# |    clip_fraction        | 0.00972       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.163        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 146           |
# |    n_updates            | 6000          |
# |    policy_gradient_loss | -0.00103      |
# |    value_loss           | 236           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 602           |
# |    time_elapsed         | 1510          |
# |    total_timesteps      | 1232896       |
# | train/                  |               |
# |    approx_kl            | 0.00078821694 |
# |    clip_fraction        | 0.0111        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.166        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 177           |
# |    n_updates            | 6010          |
# |    policy_gradient_loss | -0.00105      |
# |    value_loss           | 327           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 603          |
# |    time_elapsed         | 1513         |
# |    total_timesteps      | 1234944      |
# | train/                  |              |
# |    approx_kl            | 0.0008550679 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.172       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 136          |
# |    n_updates            | 6020         |
# |    policy_gradient_loss | -0.000862    |
# |    value_loss           | 230          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 604           |
# |    time_elapsed         | 1515          |
# |    total_timesteps      | 1236992       |
# | train/                  |               |
# |    approx_kl            | 0.00070739473 |
# |    clip_fraction        | 0.00801       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.183        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 115           |
# |    n_updates            | 6030          |
# |    policy_gradient_loss | -0.00067      |
# |    value_loss           | 241           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 605          |
# |    time_elapsed         | 1518         |
# |    total_timesteps      | 1239040      |
# | train/                  |              |
# |    approx_kl            | 0.0009640028 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.171       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 6040         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 242          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 606          |
# |    time_elapsed         | 1520         |
# |    total_timesteps      | 1241088      |
# | train/                  |              |
# |    approx_kl            | 0.0011894518 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.167       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 70.9         |
# |    n_updates            | 6050         |
# |    policy_gradient_loss | -0.000934    |
# |    value_loss           | 204          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 607           |
# |    time_elapsed         | 1523          |
# |    total_timesteps      | 1243136       |
# | train/                  |               |
# |    approx_kl            | 0.00041489254 |
# |    clip_fraction        | 0.00679       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.181        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 96.7          |
# |    n_updates            | 6060          |
# |    policy_gradient_loss | -0.0009       |
# |    value_loss           | 230           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 608          |
# |    time_elapsed         | 1525         |
# |    total_timesteps      | 1245184      |
# | train/                  |              |
# |    approx_kl            | 0.0010593768 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.177       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 150          |
# |    n_updates            | 6070         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 279          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 609          |
# |    time_elapsed         | 1528         |
# |    total_timesteps      | 1247232      |
# | train/                  |              |
# |    approx_kl            | 0.0006296954 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.6         |
# |    n_updates            | 6080         |
# |    policy_gradient_loss | -0.000962    |
# |    value_loss           | 177          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 816           |
# |    iterations           | 610           |
# |    time_elapsed         | 1530          |
# |    total_timesteps      | 1249280       |
# | train/                  |               |
# |    approx_kl            | 0.00087924907 |
# |    clip_fraction        | 0.00771       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.189        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 83.2          |
# |    n_updates            | 6090          |
# |    policy_gradient_loss | -0.000561     |
# |    value_loss           | 176           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 611          |
# |    time_elapsed         | 1533         |
# |    total_timesteps      | 1251328      |
# | train/                  |              |
# |    approx_kl            | 0.0009650841 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.178       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 6100         |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 266          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 612          |
# |    time_elapsed         | 1535         |
# |    total_timesteps      | 1253376      |
# | train/                  |              |
# |    approx_kl            | 0.0010306265 |
# |    clip_fraction        | 0.00981      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.176       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 6110         |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 221          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 613          |
# |    time_elapsed         | 1538         |
# |    total_timesteps      | 1255424      |
# | train/                  |              |
# |    approx_kl            | 0.0011797354 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 6120         |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 206          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 63
#      60 model.set_logger(new_logger)
#      62 # 학습
# ---> 63 model.learn(total_timesteps=100000000)
#      65 # 로그 파일 경로 확인
#      66 print(f"Logs saved in directory: {log_dir}")
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/policies.py:656, in ActorCriticPolicy.forward(self, obs, deterministic)
#     654 distribution = self._get_action_dist_from_latent(latent_pi)
#     655 actions = distribution.get_actions(deterministic=deterministic)
# --> 656 log_prob = distribution.log_prob(actions)
#     657 actions = actions.reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#     658 return actions, values, log_prob
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/distributions.py:399, in BernoulliDistribution.log_prob(self, actions)
#     398 def log_prob(self, actions: th.Tensor) -> th.Tensor:
# --> 399     return self.distribution.log_prob(actions).sum(dim=1)
#
# File /usr/local/lib/python3.8/dist-packages/torch/distributions/bernoulli.py:112, in Bernoulli.log_prob(self, value)
#     110     self._validate_sample(value)
#     111 logits, value = broadcast_all(self.logits, value)
# --> 112 return -binary_cross_entropy_with_logits(logits, value, reduction="none")
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:3244, in binary_cross_entropy_with_logits(input, target, weight, size_average, reduce, reduction, pos_weight)
#    3241 if not (target.size() == input.size()):
#    3242     raise ValueError(f"Target size ({target.size()}) must be the same as input size ({input.size()})")
# -> 3244 return torch.binary_cross_entropy_with_logits(input, target, weight, pos_weight, reduction_enum)
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
