# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=36, energy_limit=72):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 36  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=72)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=5000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_36/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2504 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1699        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011595106 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | -0.000479   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.71e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 2.04e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1477        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011434387 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | -5.14e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 2.21e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1425        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010233453 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.9       |
# |    explained_variance   | -1.8e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+04    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 2.24e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1417         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0120984055 |
# |    clip_fraction        | 0.196        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -24.9        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.025       |
# |    value_loss           | 2.26e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1395        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013882485 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.8       |
# |    explained_variance   | -2.98e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+04    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 2.34e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1390        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.012409671 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.026      |
# |    value_loss           | 2.32e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012191918 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.7       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0274     |
# |    value_loss           | 2.38e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1339        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012953938 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.6       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 2.4e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1345        |
# |    iterations           | 10          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009517156 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.5       |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 2.46e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1359       |
# |    iterations           | 11         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01145667 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -24.5      |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18e+04   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0267    |
# |    value_loss           | 2.44e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1369        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012222198 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.4       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 2.58e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1373        |
# |    iterations           | 13          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010677796 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24.3       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 2.54e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1375         |
# |    iterations           | 14           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0119528705 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -24.2        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.24e+04     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0235      |
# |    value_loss           | 2.58e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1379        |
# |    iterations           | 15          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012223703 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -24         |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 2.61e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1384       |
# |    iterations           | 16         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01175778 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.9      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.29e+04   |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0254    |
# |    value_loss           | 2.68e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010710495 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+04    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0243     |
# |    value_loss           | 2.66e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1382       |
# |    iterations           | 18         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00982693 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.7      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+04   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0261    |
# |    value_loss           | 2.68e+04   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1387       |
# |    iterations           | 19         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01432302 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -23.5      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.32e+04   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.03      |
# |    value_loss           | 2.78e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1374        |
# |    iterations           | 20          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012929549 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42e+04    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0247     |
# |    value_loss           | 2.89e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1371        |
# |    iterations           | 21          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010547813 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 2.89e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1367        |
# |    iterations           | 22          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011080486 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -23         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+04    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 3e+04       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1367         |
# |    iterations           | 23           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0094546825 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -22.9        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+04      |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0186      |
# |    value_loss           | 2.97e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1368        |
# |    iterations           | 24          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010839494 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 2.97e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1369        |
# |    iterations           | 25          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011247632 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0215     |
# |    value_loss           | 3.05e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1370        |
# |    iterations           | 26          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011025932 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5e+04     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 3.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1369        |
# |    iterations           | 27          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009908356 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -22.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 3.02e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1370        |
# |    iterations           | 28          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011352267 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 3.16e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1372        |
# |    iterations           | 29          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.009529344 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+04    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 3.09e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1374        |
# |    iterations           | 30          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012261488 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56e+04    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 3.19e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1373        |
# |    iterations           | 31          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011998899 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 3.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 32          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011710744 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.9       |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 3.23e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 33          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.012438463 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 3.34e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 34          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011159501 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+04    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 3.32e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 35          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012075921 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+04    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 3.36e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 36          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010335861 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -20         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 3.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1374        |
# |    iterations           | 37          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011584622 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.7       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 3.57e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1371        |
# |    iterations           | 38          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011874235 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+04    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 3.5e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1370        |
# |    iterations           | 39          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.010109783 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65e+04    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 3.48e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1368        |
# |    iterations           | 40          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010281583 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -19         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 3.53e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1365        |
# |    iterations           | 41          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.013228962 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.7       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 3.41e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 42          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009676504 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 3.55e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1362       |
# |    iterations           | 43         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.01094448 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -18.2      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.76e+04   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 3.65e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 44          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011042165 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -18         |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 3.71e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 45          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011577075 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.8       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+04    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 3.55e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 46          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014031144 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.77e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 3.68e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 47          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010167121 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -17.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+04    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 3.67e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 48          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011819401 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79e+04    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 3.68e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 49          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011613393 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 3.67e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 50          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008843003 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -16.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 3.67e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 51          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.013472323 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 3.73e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1358       |
# |    iterations           | 52         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.00937498 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15.5      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.81e+04   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0133    |
# |    value_loss           | 3.8e+04    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 53          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009994814 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85e+04    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00908    |
# |    value_loss           | 3.8e+04     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1362       |
# |    iterations           | 54         |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01073238 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.88e+04   |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 3.93e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1362        |
# |    iterations           | 55          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.011544146 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+04    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 3.86e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1363        |
# |    iterations           | 56          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012037244 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.6       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89e+04    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 3.93e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1365        |
# |    iterations           | 57          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.011148561 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 3.81e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1367         |
# |    iterations           | 58           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0129218055 |
# |    clip_fraction        | 0.18         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.1        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.83e+04     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 3.79e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1368        |
# |    iterations           | 59          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.011860004 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.85e+04    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 3.78e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1370        |
# |    iterations           | 60          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.011431253 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84e+04    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 3.89e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1372        |
# |    iterations           | 61          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.012857789 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.4       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93e+04    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 3.93e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1373       |
# |    iterations           | 62         |
# |    time_elapsed         | 92         |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.00990455 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.86e+04   |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0124    |
# |    value_loss           | 3.87e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1373        |
# |    iterations           | 63          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.010431717 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -12.7       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92e+04    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 3.89e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1375        |
# |    iterations           | 64          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.011560002 |
# ...
# |    loss                 | 60.9          |
# |    n_updates            | 3860          |
# |    policy_gradient_loss | -0.000414     |
# |    value_loss           | 133           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 388           |
# |    time_elapsed         | 569           |
# |    total_timesteps      | 794624        |
# | train/                  |               |
# |    approx_kl            | 0.00062291836 |
# |    clip_fraction        | 0.00684       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.1          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 55            |
# |    n_updates            | 3870          |
# |    policy_gradient_loss | -0.000434     |
# |    value_loss           | 133           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 389           |
# |    time_elapsed         | 570           |
# |    total_timesteps      | 796672        |
# | train/                  |               |
# |    approx_kl            | 0.00042568857 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.109        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.5          |
# |    n_updates            | 3880          |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 130           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 390          |
# |    time_elapsed         | 572          |
# |    total_timesteps      | 798720       |
# | train/                  |              |
# |    approx_kl            | 0.0004960503 |
# |    clip_fraction        | 0.00801      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.106       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 69.4         |
# |    n_updates            | 3890         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 133          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 391           |
# |    time_elapsed         | 573           |
# |    total_timesteps      | 800768        |
# | train/                  |               |
# |    approx_kl            | 0.00029708893 |
# |    clip_fraction        | 0.00454       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.101        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 70.4          |
# |    n_updates            | 3900          |
# |    policy_gradient_loss | -0.000853     |
# |    value_loss           | 137           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 392           |
# |    time_elapsed         | 575           |
# |    total_timesteps      | 802816        |
# | train/                  |               |
# |    approx_kl            | 0.00037057063 |
# |    clip_fraction        | 0.00479       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0953       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 73.8          |
# |    n_updates            | 3910          |
# |    policy_gradient_loss | -0.000354     |
# |    value_loss           | 128           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 393           |
# |    time_elapsed         | 576           |
# |    total_timesteps      | 804864        |
# | train/                  |               |
# |    approx_kl            | 0.00049318216 |
# |    clip_fraction        | 0.00513       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0974       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 35.5          |
# |    n_updates            | 3920          |
# |    policy_gradient_loss | -0.000379     |
# |    value_loss           | 113           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1394          |
# |    iterations           | 394           |
# |    time_elapsed         | 578           |
# |    total_timesteps      | 806912        |
# | train/                  |               |
# |    approx_kl            | 0.00049888424 |
# |    clip_fraction        | 0.00522       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0982       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 57.6          |
# |    n_updates            | 3930          |
# |    policy_gradient_loss | -0.000437     |
# |    value_loss           | 130           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 395           |
# |    time_elapsed         | 579           |
# |    total_timesteps      | 808960        |
# | train/                  |               |
# |    approx_kl            | 0.00060359144 |
# |    clip_fraction        | 0.00649       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.116        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 95.8          |
# |    n_updates            | 3940          |
# |    policy_gradient_loss | -0.000919     |
# |    value_loss           | 172           |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1395        |
# |    iterations           | 396         |
# |    time_elapsed         | 581         |
# |    total_timesteps      | 811008      |
# | train/                  |             |
# |    approx_kl            | 0.000912803 |
# |    clip_fraction        | 0.00747     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 3950        |
# |    policy_gradient_loss | -0.000428   |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 397          |
# |    time_elapsed         | 582          |
# |    total_timesteps      | 813056       |
# | train/                  |              |
# |    approx_kl            | 0.0009280903 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.111       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.2         |
# |    n_updates            | 3960         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 146          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 398           |
# |    time_elapsed         | 584           |
# |    total_timesteps      | 815104        |
# | train/                  |               |
# |    approx_kl            | 0.00058163167 |
# |    clip_fraction        | 0.00615       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.117        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 44.9          |
# |    n_updates            | 3970          |
# |    policy_gradient_loss | -0.000922     |
# |    value_loss           | 95            |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 399           |
# |    time_elapsed         | 585           |
# |    total_timesteps      | 817152        |
# | train/                  |               |
# |    approx_kl            | 0.00032738544 |
# |    clip_fraction        | 0.00459       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.123        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 66.2          |
# |    n_updates            | 3980          |
# |    policy_gradient_loss | -0.000509     |
# |    value_loss           | 133           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 400           |
# |    time_elapsed         | 586           |
# |    total_timesteps      | 819200        |
# | train/                  |               |
# |    approx_kl            | 0.00039342607 |
# |    clip_fraction        | 0.00605       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.118        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 67.1          |
# |    n_updates            | 3990          |
# |    policy_gradient_loss | -0.000617     |
# |    value_loss           | 144           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 401          |
# |    time_elapsed         | 588          |
# |    total_timesteps      | 821248       |
# | train/                  |              |
# |    approx_kl            | 0.0003584245 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.12        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.8         |
# |    n_updates            | 4000         |
# |    policy_gradient_loss | -0.000513    |
# |    value_loss           | 103          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 402           |
# |    time_elapsed         | 589           |
# |    total_timesteps      | 823296        |
# | train/                  |               |
# |    approx_kl            | 0.00035394973 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.109        |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 82.2          |
# |    n_updates            | 4010          |
# |    policy_gradient_loss | -0.000609     |
# |    value_loss           | 130           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1396          |
# |    iterations           | 403           |
# |    time_elapsed         | 591           |
# |    total_timesteps      | 825344        |
# | train/                  |               |
# |    approx_kl            | 0.00052094454 |
# |    clip_fraction        | 0.00435       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.102        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 56.6          |
# |    n_updates            | 4020          |
# |    policy_gradient_loss | -0.000837     |
# |    value_loss           | 114           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 404           |
# |    time_elapsed         | 592           |
# |    total_timesteps      | 827392        |
# | train/                  |               |
# |    approx_kl            | 0.00072909833 |
# |    clip_fraction        | 0.00703       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.095        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 63.5          |
# |    n_updates            | 4030          |
# |    policy_gradient_loss | -0.000585     |
# |    value_loss           | 118           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 405           |
# |    time_elapsed         | 594           |
# |    total_timesteps      | 829440        |
# | train/                  |               |
# |    approx_kl            | 0.00032162343 |
# |    clip_fraction        | 0.00415       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.094        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 86.6          |
# |    n_updates            | 4040          |
# |    policy_gradient_loss | -0.000873     |
# |    value_loss           | 126           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 406           |
# |    time_elapsed         | 595           |
# |    total_timesteps      | 831488        |
# | train/                  |               |
# |    approx_kl            | 0.00019001204 |
# |    clip_fraction        | 0.00483       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0964       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.9          |
# |    n_updates            | 4050          |
# |    policy_gradient_loss | -0.000596     |
# |    value_loss           | 119           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1395          |
# |    iterations           | 407           |
# |    time_elapsed         | 597           |
# |    total_timesteps      | 833536        |
# | train/                  |               |
# |    approx_kl            | 0.00027811655 |
# |    clip_fraction        | 0.00405       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0987       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.9          |
# |    n_updates            | 4060          |
# |    policy_gradient_loss | -0.0002       |
# |    value_loss           | 121           |
# -------------------------------------------

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
