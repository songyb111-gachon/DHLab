# %%
import numpy as np
import gymnasium as gym
from gymnasium.spaces import MultiBinary
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.logger import configure
import os
import pandas as pd
import matplotlib.pyplot as plt

# 스마트 팩토리 환경 생성
class SmartFactoryEnv(gym.Env):
    def __init__(self, n_machines=324, energy_limit=648):
        super(SmartFactoryEnv, self).__init__()
        self.n_machines = n_machines
        self.energy_limit = energy_limit

        # Multi-Binary 행동 공간
        self.action_space = MultiBinary(n_machines)

        # 관찰 공간
        self.observation_space = gym.spaces.Box(
            low=0, high=1, shape=(n_machines + 1,), dtype=float
        )

        self.state = None

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.state = np.zeros(self.n_machines + 1, dtype=float)
        return self.state, {}

    def step(self, action):
        energy_usage = np.dot(np.random.uniform(1, 2, self.n_machines), action)
        production = np.dot(np.random.uniform(1, 3, self.n_machines), action)
        penalty = max(0, energy_usage - self.energy_limit)
        reward = production - energy_usage - penalty

        self.state = np.concatenate([action, [energy_usage]])

        done = energy_usage > self.energy_limit * 2
        return self.state, reward, done, False, {}

    def render(self):
        print(f"Machines: {self.state[:-1]}, Energy Usage: {self.state[-1]}")

# 환경 설정
n_machines = 324  # MultiBinary 행동 공간 크기
env = DummyVecEnv([lambda: SmartFactoryEnv(n_machines=n_machines, energy_limit=648)])

# 로그 저장 디렉토리 설정 및 사용자 지정 이름 생성
log_dir = f"./logs_binary_{n_machines}/"
os.makedirs(log_dir, exist_ok=True)  # 디렉토리가 없으면 생성

# 사용자 정의 로거 설정
new_logger = configure(log_dir, ["stdout", "csv", "tensorboard"])

# PPO 모델 생성
model = PPO("MlpPolicy", env, verbose=1)
model.set_logger(new_logger)

# 학습
model.learn(total_timesteps=100000000)

# 로그 파일 경로 확인
print(f"Logs saved in directory: {log_dir}")
# Out:
# Logging to ./logs_binary_324/
# Using cuda device
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# -----------------------------
# | time/              |      |
# |    fps             | 2352 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.029280374 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -225        |
# |    explained_variance   | 2.81e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.92e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0368     |
# |    value_loss           | 1.8e+06     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1539       |
# |    iterations           | 3          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02803104 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -225       |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.22e+05   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0379    |
# |    value_loss           | 1.84e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1450        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.026151955 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.09e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0348     |
# |    value_loss           | 1.83e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.027346697 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.22e+05    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 1.87e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1410        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024368178 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.21e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 1.86e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1394        |
# |    iterations           | 7           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.025671218 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.36e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 1.88e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1391        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.025468105 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.49e+05    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0374     |
# |    value_loss           | 1.9e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1392        |
# |    iterations           | 9           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026838366 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.5e+05     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 1.89e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1376        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023850895 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.63e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.036      |
# |    value_loss           | 1.92e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1369        |
# |    iterations           | 11          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.026461085 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.7e+05     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0381     |
# |    value_loss           | 1.93e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1371        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.026458628 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.69e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 1.93e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1364       |
# |    iterations           | 13         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.02859611 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -224       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.8e+05    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0373    |
# |    value_loss           | 1.95e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1363        |
# |    iterations           | 14          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.028018057 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.64e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 1.95e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1365        |
# |    iterations           | 15          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025606941 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.82e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 1.98e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 16          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.026565557 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.88e+05    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 1.98e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.028003957 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -224        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+06    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 2.01e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1356        |
# |    iterations           | 18          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.027976893 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.91e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 2.01e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1358        |
# |    iterations           | 19          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.024955675 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.8e+05     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 2.03e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1353        |
# |    iterations           | 20          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.024583098 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+06    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 2.03e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1355        |
# |    iterations           | 21          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.025222123 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+06       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0363     |
# |    value_loss           | 2.03e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 22          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.027470168 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+06    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 2.05e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1354        |
# |    iterations           | 23          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.026916124 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+06    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0359     |
# |    value_loss           | 2.08e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1349       |
# |    iterations           | 24         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.02770083 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -223       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+06   |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0356    |
# |    value_loss           | 2.06e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1350        |
# |    iterations           | 25          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.024975002 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+06    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.033      |
# |    value_loss           | 2.06e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 26          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.024724977 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+06    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0329     |
# |    value_loss           | 2.08e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1352        |
# |    iterations           | 27          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.026502397 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -223        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+06    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0375     |
# |    value_loss           | 2.11e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1351       |
# |    iterations           | 28         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.02744231 |
# |    clip_fraction        | 0.314      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -222       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.04e+06   |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0391    |
# |    value_loss           | 2.11e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 29          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.025952697 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -222        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+06    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 2.12e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1348        |
# |    iterations           | 30          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.028351866 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -222        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+06    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 2.13e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 31          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.028436653 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -222        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+06    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 2.14e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 32          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.027174274 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -222        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+06    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 2.16e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 33          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.027357355 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -222        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+06    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 2.18e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1341        |
# |    iterations           | 34          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.026525736 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -221        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+06    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.033      |
# |    value_loss           | 2.18e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 35          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.026083628 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -221        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+06    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 2.17e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 36          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.028168729 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -221        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1e+06     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 2.2e+06     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1341       |
# |    iterations           | 37         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.02631355 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -221       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.11e+06   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0326    |
# |    value_loss           | 2.2e+06    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1343        |
# |    iterations           | 38          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.025474653 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -221        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+06    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0335     |
# |    value_loss           | 2.22e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1342        |
# |    iterations           | 39          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.030333705 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -221        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+06    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 2.23e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 40          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.029239152 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -220        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+06    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 2.24e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 41          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028882988 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -220        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+06    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 2.26e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1334        |
# |    iterations           | 42          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.027608091 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -220        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+06    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0341     |
# |    value_loss           | 2.27e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 43          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.030452546 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -220        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+06    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 2.28e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 44          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.026421446 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -220        |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+06    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0311     |
# |    value_loss           | 2.3e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 45          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.028897777 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+06    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0337     |
# |    value_loss           | 2.31e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1333        |
# |    iterations           | 46          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.027363073 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+06    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 2.31e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 47          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.028180754 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+06    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 2.32e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 48          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.029877696 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -219        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+06    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0349     |
# |    value_loss           | 2.35e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 49          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.027245633 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+06    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0332     |
# |    value_loss           | 2.34e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 50          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.025954522 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+06    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0327     |
# |    value_loss           | 2.36e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1330       |
# |    iterations           | 51         |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.03023858 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -218       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.16e+06   |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0354    |
# |    value_loss           | 2.36e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 52          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.027672619 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+06     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 2.37e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1328        |
# |    iterations           | 53          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.026286297 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -218        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+06    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0321     |
# |    value_loss           | 2.39e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 54          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.027855225 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -217        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+06    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 2.4e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 55          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.029763091 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -217        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19e+06    |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0364     |
# |    value_loss           | 2.4e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 56          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.030878283 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -217        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21e+06    |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 2.42e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 57          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.025922589 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -217        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+06    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0327     |
# |    value_loss           | 2.44e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1326        |
# |    iterations           | 58          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.029180584 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -217        |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+06    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 2.45e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 59          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.029976463 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -216        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+06     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 2.44e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1324        |
# |    iterations           | 60          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.030528791 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -216        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+06    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0352     |
# |    value_loss           | 2.46e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 61          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.029870164 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -216        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+06    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 2.46e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 62          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.029495161 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -216        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+06    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0339     |
# |    value_loss           | 2.5e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 63          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.027090952 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -215        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23e+06    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 2.48e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1325        |
# |    iterations           | 64          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.030805446 |
# |    clip_fraction        | 0.312       |
# ...
# |    approx_kl            | 0.01197833 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 456        |
# |    n_updates            | 27060      |
# |    policy_gradient_loss | -0.00869   |
# |    value_loss           | 1.03e+03   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2708        |
# |    time_elapsed         | 4259        |
# |    total_timesteps      | 5545984     |
# | train/                  |             |
# |    approx_kl            | 0.009244454 |
# |    clip_fraction        | 0.0919      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 786         |
# |    n_updates            | 27070       |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 1.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2709        |
# |    time_elapsed         | 4260        |
# |    total_timesteps      | 5548032     |
# | train/                  |             |
# |    approx_kl            | 0.010629298 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 987         |
# |    n_updates            | 27080       |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2710        |
# |    time_elapsed         | 4262        |
# |    total_timesteps      | 5550080     |
# | train/                  |             |
# |    approx_kl            | 0.010085925 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 601         |
# |    n_updates            | 27090       |
# |    policy_gradient_loss | -0.0074     |
# |    value_loss           | 1.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2711        |
# |    time_elapsed         | 4263        |
# |    total_timesteps      | 5552128     |
# | train/                  |             |
# |    approx_kl            | 0.009544798 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 445         |
# |    n_updates            | 27100       |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 1.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2712        |
# |    time_elapsed         | 4265        |
# |    total_timesteps      | 5554176     |
# | train/                  |             |
# |    approx_kl            | 0.009461674 |
# |    clip_fraction        | 0.0815      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 663         |
# |    n_updates            | 27110       |
# |    policy_gradient_loss | -0.00907    |
# |    value_loss           | 956         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2713        |
# |    time_elapsed         | 4266        |
# |    total_timesteps      | 5556224     |
# | train/                  |             |
# |    approx_kl            | 0.008193253 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 322         |
# |    n_updates            | 27120       |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1302         |
# |    iterations           | 2714         |
# |    time_elapsed         | 4268         |
# |    total_timesteps      | 5558272      |
# | train/                  |              |
# |    approx_kl            | 0.0103518525 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 656          |
# |    n_updates            | 27130        |
# |    policy_gradient_loss | -0.00754     |
# |    value_loss           | 1.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1302         |
# |    iterations           | 2715         |
# |    time_elapsed         | 4270         |
# |    total_timesteps      | 5560320      |
# | train/                  |              |
# |    approx_kl            | 0.0064273505 |
# |    clip_fraction        | 0.0943       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 634          |
# |    n_updates            | 27140        |
# |    policy_gradient_loss | -0.00668     |
# |    value_loss           | 1.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2716        |
# |    time_elapsed         | 4271        |
# |    total_timesteps      | 5562368     |
# | train/                  |             |
# |    approx_kl            | 0.008962881 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 438         |
# |    n_updates            | 27150       |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 1e+03       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1302         |
# |    iterations           | 2717         |
# |    time_elapsed         | 4273         |
# |    total_timesteps      | 5564416      |
# | train/                  |              |
# |    approx_kl            | 0.0067867795 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 517          |
# |    n_updates            | 27160        |
# |    policy_gradient_loss | -0.00765     |
# |    value_loss           | 1.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2718        |
# |    time_elapsed         | 4275        |
# |    total_timesteps      | 5566464     |
# | train/                  |             |
# |    approx_kl            | 0.007626086 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 409         |
# |    n_updates            | 27170       |
# |    policy_gradient_loss | -0.00844    |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2719        |
# |    time_elapsed         | 4276        |
# |    total_timesteps      | 5568512     |
# | train/                  |             |
# |    approx_kl            | 0.008604859 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 460         |
# |    n_updates            | 27180       |
# |    policy_gradient_loss | -0.00765    |
# |    value_loss           | 852         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2720        |
# |    time_elapsed         | 4278        |
# |    total_timesteps      | 5570560     |
# | train/                  |             |
# |    approx_kl            | 0.009226967 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 407         |
# |    n_updates            | 27190       |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 977         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2721        |
# |    time_elapsed         | 4279        |
# |    total_timesteps      | 5572608     |
# | train/                  |             |
# |    approx_kl            | 0.006918208 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 530         |
# |    n_updates            | 27200       |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2722        |
# |    time_elapsed         | 4281        |
# |    total_timesteps      | 5574656     |
# | train/                  |             |
# |    approx_kl            | 0.007880401 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 490         |
# |    n_updates            | 27210       |
# |    policy_gradient_loss | -0.00708    |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1302        |
# |    iterations           | 2723        |
# |    time_elapsed         | 4282        |
# |    total_timesteps      | 5576704     |
# | train/                  |             |
# |    approx_kl            | 0.008571278 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 626         |
# |    n_updates            | 27220       |
# |    policy_gradient_loss | -0.00804    |
# |    value_loss           | 1.13e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1302       |
# |    iterations           | 2724       |
# |    time_elapsed         | 4284       |
# |    total_timesteps      | 5578752    |
# | train/                  |            |
# |    approx_kl            | 0.01129487 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.88      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 479        |
# |    n_updates            | 27230      |
# |    policy_gradient_loss | -0.00781   |
# |    value_loss           | 1.24e+03   |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 63
#      60 model.set_logger(new_logger)
#      62 # 학습
# ---> 63 model.learn(total_timesteps=100000000)
#      65 # 로그 파일 경로 확인
#      66 print(f"Logs saved in directory: {log_dir}")
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/on_policy_algorithm.py:247, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     244             terminal_value = self.policy.predict_values(terminal_obs)[0]  # type: ignore[arg-type]
#     245         rewards[idx] += self.gamma * terminal_value
# --> 247 rollout_buffer.add(
#     248     self._last_obs,  # type: ignore[arg-type]
#     249     actions,
#     250     rewards,
#     251     self._last_episode_starts,  # type: ignore[arg-type]
#     252     values,
#     253     log_probs,
#     254 )
#     255 self._last_obs = new_obs  # type: ignore[assignment]
#     256 self._last_episode_starts = dones
#
# File /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/buffers.py:475, in RolloutBuffer.add(self, obs, action, reward, episode_start, value, log_prob)
#     473 self.episode_starts[self.pos] = np.array(episode_start)
#     474 self.values[self.pos] = value.clone().cpu().numpy().flatten()
# --> 475 self.log_probs[self.pos] = log_prob.clone().cpu().numpy()
#     476 self.pos += 1
#     477 if self.pos == self.buffer_size:
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# 로그 데이터 시각화
log_csv_path = os.path.join(log_dir, "progress.csv")  # log_dir은 이전에 정의된 디렉토리 변수

# CSV 파일 읽기 및 그래프 그리기
if os.path.exists(log_csv_path):
    data = pd.read_csv(log_csv_path)

    plt.figure(figsize=(10, 6))
    plt.plot(data["time/total_timesteps"], data["train/value_loss"], label="Value Loss")
    plt.plot(data["time/total_timesteps"], data["train/policy_gradient_loss"], label="Policy Gradient Loss")
    plt.xlabel("Timesteps")
    plt.ylabel("Loss")
    plt.title(f"Training Loss Over Timesteps (Binary {n_machines})")
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Log CSV file not found. Ensure training has completed successfully.")
